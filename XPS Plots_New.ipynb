# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Libraries" data-toc-modified-id="Libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Libraries</a></span></li><li><span><a href="#Functions" data-toc-modified-id="Functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Functions</a></span></li><li><span><a href="#Main" data-toc-modified-id="Main-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Main</a></span></li><li><span><a href="#use-this-set-of-parameters-when-there-is-first-middle-then-upstream" data-toc-modified-id="use-this-set-of-parameters-when-there-is-first-middle-then-upstream-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>use this set of parameters when there is first middle then upstream</a></span><ul class="toc-item"><li><span><a href="#HOPG" data-toc-modified-id="HOPG-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>HOPG</a></span></li><li><span><a href="#Au" data-toc-modified-id="Au-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Au</a></span></li><li><span><a href="#Si" data-toc-modified-id="Si-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Si</a></span></li><li><span><a href="#PTFE" data-toc-modified-id="PTFE-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>PTFE</a></span></li><li><span><a href="#Al" data-toc-modified-id="Al-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Al</a></span></li></ul></li><li><span><a href="#Comparison-among-substrates" data-toc-modified-id="Comparison-among-substrates-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Comparison among substrates</a></span></li><li><span><a href="#Graphs-a.u." data-toc-modified-id="Graphs-a.u.-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Graphs a.u.</a></span></li><li><span><a href="#Graphs" data-toc-modified-id="Graphs-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Graphs</a></span></li><li><span><a href="#Wide" data-toc-modified-id="Wide-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Wide</a></span></li><li><span><a href="#Wide-subplots" data-toc-modified-id="Wide-subplots-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Wide subplots</a></span></li><li><span><a href="#Several-spectra" data-toc-modified-id="Several-spectra-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Several spectra</a></span><ul class="toc-item"><li><span><a href="#5s" data-toc-modified-id="5s-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>5s</a></span></li><li><span><a href="#600-s" data-toc-modified-id="600-s-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>600 s</a></span></li></ul></li><li><span><a href="#Poster" data-toc-modified-id="Poster-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Poster</a></span></li><li><span><a href="#Annealing" data-toc-modified-id="Annealing-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Annealing</a></span></li><li><span><a href="#Non-polymerised-TEMPO" data-toc-modified-id="Non-polymerised-TEMPO-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Non-polymerised TEMPO</a></span></li><li><span><a href="#Paper" data-toc-modified-id="Paper-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Paper</a></span><ul class="toc-item"><li><span><a href="#Fitted-Data" data-toc-modified-id="Fitted-Data-14.1"><span class="toc-item-num">14.1&nbsp;&nbsp;</span>Fitted Data</a></span></li><li><span><a href="#Overlapped-Spectra" data-toc-modified-id="Overlapped-Spectra-14.2"><span class="toc-item-num">14.2&nbsp;&nbsp;</span>Overlapped Spectra</a></span></li><li><span><a href="#Wide-Spectra" data-toc-modified-id="Wide-Spectra-14.3"><span class="toc-item-num">14.3&nbsp;&nbsp;</span>Wide Spectra</a></span></li></ul></li><li><span><a href="#Overlapped-spectra-+-PTFE" data-toc-modified-id="Overlapped-spectra-+-PTFE-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>Overlapped spectra + PTFE</a></span></li><li><span><a href="#Antiviral-XPS" data-toc-modified-id="Antiviral-XPS-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>Antiviral XPS</a></span></li><li><span><a href="#OCCA-Examples" data-toc-modified-id="OCCA-Examples-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>OCCA Examples</a></span><ul class="toc-item"><li><span><a href="#C1s" data-toc-modified-id="C1s-17.1"><span class="toc-item-num">17.1&nbsp;&nbsp;</span>C1s</a></span></li><li><span><a href="#N-1s" data-toc-modified-id="N-1s-17.2"><span class="toc-item-num">17.2&nbsp;&nbsp;</span>N 1s</a></span></li><li><span><a href="#Depth-profiling" data-toc-modified-id="Depth-profiling-17.3"><span class="toc-item-num">17.3&nbsp;&nbsp;</span>Depth profiling</a></span><ul class="toc-item"><li><span><a href="#Bad-quality" data-toc-modified-id="Bad-quality-17.3.1"><span class="toc-item-num">17.3.1&nbsp;&nbsp;</span>Bad quality</a></span></li><li><span><a href="#Bad-quality-data" data-toc-modified-id="Bad-quality-data-17.3.2"><span class="toc-item-num">17.3.2&nbsp;&nbsp;</span>Bad quality data</a></span></li></ul></li></ul></li><li><span><a href="#Cu-5" data-toc-modified-id="Cu-5-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>Cu 5</a></span><ul class="toc-item"><li><span><a href="#HOPG" data-toc-modified-id="HOPG-18.1"><span class="toc-item-num">18.1&nbsp;&nbsp;</span>HOPG</a></span><ul class="toc-item"><li><span><a href="#Cu-2p" data-toc-modified-id="Cu-2p-18.1.1"><span class="toc-item-num">18.1.1&nbsp;&nbsp;</span>Cu 2p</a></span></li><li><span><a href="#Cu-3p-of-Br4TPP+-Cu$_5$-at-different-T" data-toc-modified-id="Cu-3p-of-Br4TPP+-Cu$_5$-at-different-T-18.1.2"><span class="toc-item-num">18.1.2&nbsp;&nbsp;</span>Cu 3p of Br4TPP+ Cu$_5$ at different T</a></span></li><li><span><a href="#Auger" data-toc-modified-id="Auger-18.1.3"><span class="toc-item-num">18.1.3&nbsp;&nbsp;</span>Auger</a></span></li><li><span><a href="#Auger-Better-quality" data-toc-modified-id="Auger-Better-quality-18.1.4"><span class="toc-item-num">18.1.4&nbsp;&nbsp;</span>Auger Better quality</a></span></li><li><span><a href="#Auger-Right-Range" data-toc-modified-id="Auger-Right-Range-18.1.5"><span class="toc-item-num">18.1.5&nbsp;&nbsp;</span>Auger Right Range</a></span></li><li><span><a href="#Auger-Right-Range--2" data-toc-modified-id="Auger-Right-Range--2-18.1.6"><span class="toc-item-num">18.1.6&nbsp;&nbsp;</span>Auger Right Range -2</a></span></li></ul></li><li><span><a href="#Au(111)" data-toc-modified-id="Au(111)-18.2"><span class="toc-item-num">18.2&nbsp;&nbsp;</span>Au(111)</a></span><ul class="toc-item"><li><span><a href="#Cu-2p" data-toc-modified-id="Cu-2p-18.2.1"><span class="toc-item-num">18.2.1&nbsp;&nbsp;</span>Cu 2p</a></span></li><li><span><a href="#Auger" data-toc-modified-id="Auger-18.2.2"><span class="toc-item-num">18.2.2&nbsp;&nbsp;</span>Auger</a></span></li><li><span><a href="#Auger-Improved-quality" data-toc-modified-id="Auger-Improved-quality-18.2.3"><span class="toc-item-num">18.2.3&nbsp;&nbsp;</span>Auger Improved quality</a></span></li></ul></li><li><span><a href="#Auger-Au(111-control)" data-toc-modified-id="Auger-Au(111-control)-18.3"><span class="toc-item-num">18.3&nbsp;&nbsp;</span>Auger Au(111 control)</a></span></li><li><span><a href="#Mica" data-toc-modified-id="Mica-18.4"><span class="toc-item-num">18.4&nbsp;&nbsp;</span>Mica</a></span><ul class="toc-item"><li><span><a href="#Cu-2p" data-toc-modified-id="Cu-2p-18.4.1"><span class="toc-item-num">18.4.1&nbsp;&nbsp;</span>Cu 2p</a></span></li></ul></li></ul></li><li><span><a href="#Metalation-of-porphyrin-?" data-toc-modified-id="Metalation-of-porphyrin-?-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>Metalation of porphyrin ?</a></span><ul class="toc-item"><li><span><a href="#HOPG" data-toc-modified-id="HOPG-19.1"><span class="toc-item-num">19.1&nbsp;&nbsp;</span>HOPG</a></span></li></ul></li><li><span><a href="#Br-3p-at-different-T-for-synchrotron-papaer" data-toc-modified-id="Br-3p-at-different-T-for-synchrotron-papaer-20"><span class="toc-item-num">20&nbsp;&nbsp;</span>Br 3p at different T for synchrotron papaer</a></span></li><li><span><a href="#Yue" data-toc-modified-id="Yue-21"><span class="toc-item-num">21&nbsp;&nbsp;</span>Yue</a></span></li><li><span><a href="#Thesis" data-toc-modified-id="Thesis-22"><span class="toc-item-num">22&nbsp;&nbsp;</span>Thesis</a></span><ul class="toc-item"><li><span><a href="#Examples" data-toc-modified-id="Examples-22.1"><span class="toc-item-num">22.1&nbsp;&nbsp;</span>Examples</a></span><ul class="toc-item"><li><span><a href="#C1s" data-toc-modified-id="C1s-22.1.1"><span class="toc-item-num">22.1.1&nbsp;&nbsp;</span>C1s</a></span></li><li><span><a href="#N-1s" data-toc-modified-id="N-1s-22.1.2"><span class="toc-item-num">22.1.2&nbsp;&nbsp;</span>N 1s</a></span></li></ul></li><li><span><a href="#TEMPO" data-toc-modified-id="TEMPO-22.2"><span class="toc-item-num">22.2&nbsp;&nbsp;</span>TEMPO</a></span><ul class="toc-item"><li><span><a href="#Wide" data-toc-modified-id="Wide-22.2.1"><span class="toc-item-num">22.2.1&nbsp;&nbsp;</span>Wide</a></span></li><li><span><a href="#High-resolution" data-toc-modified-id="High-resolution-22.2.2"><span class="toc-item-num">22.2.2&nbsp;&nbsp;</span>High resolution</a></span></li><li><span><a href="#Fitted-Data" data-toc-modified-id="Fitted-Data-22.2.3"><span class="toc-item-num">22.2.3&nbsp;&nbsp;</span>Fitted Data</a></span></li><li><span><a href="#XPS-microbiology" data-toc-modified-id="XPS-microbiology-22.2.4"><span class="toc-item-num">22.2.4&nbsp;&nbsp;</span>XPS microbiology</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Libraries

# %%
import numpy as np
from scipy import stats
import pandas as pd
import XPSLibrary as xl
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

# %% [markdown]
# # Functions

# %%
#reads the XPS Data and gives meaninigful name to the columns. The colums must be 5
def ReadXPSData(FolderTR, FileXPS, DataPerSpectrum, HeaderColumns):
    XPS=pd.read_table(FolderTR+"/"+FileXPS, skiprows=lambda x: x%DataPerSpectrum<HeaderColumns, header=None)
    XPS.columns=["Kinetic energy", "Counts", "Initial Temperature", "Binding Energy", "CPS"]
    return XPS

def ReadXPSDataFitted(FolderTR, FileXPS, DataPerSpectrum, HeaderColumns, ColumnsNames):
    XPS=pd.read_table(FolderTR+"/"+FileXPS, skiprows=lambda x: x%DataPerSpectrum<HeaderColumns, header=None, sep="\t")
    XPS=XPS.dropna(axis='columns')
    XPS.columns=ColumnsNames
    return XPS


#It computer the mean of a region of CPS (greater than a setpoint named lower energy or lower than a setpoint named upper energy) 
#and subtract it to to the data for each spectrum so that all the spectra cross the zero line.
def Normalize(XPS, NumberOfSpectra, NumberOfData):  
    
    x_len=XPS.shape[0]//NumberOfSpectra
    #reshape the data to compute the mean for each spectrum
    Means=np.mean(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[0:NumberOfData],axis=0)

    #subtratct the mean to each spectrum 
    for i in range (0, NumberOfSpectra):
        XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i]-= Means[i]
    
    return XPS

#function to transform a set graph from CPS/Counts to a.u.
#It takes a counts/counts per secon column and rescale it using a reference which is the the spectrum whose intensity is 1 in tha a.u. scale
def NormalizeAU(Counts,RefMax):
    Counts= Counts/RefMax #rescale the counts
    return Counts

    
#For each spectrum, it computes the linear background and subtractit to the data
#To do so, it uses two doublets (x,y),
#they are the mean of the Point number of points at the right of the left edge and at the left of the rigth edge
def RemoveLinearBackgorund(XPS, Points, NumberOfSpectra):
    x_len=XPS.shape[0]//NumberOfSpectra

    for i in range (0, NumberOfSpectra):
        #for each spectrum compute the doublets (x,y) that will be used to calculate the slope m and intercept q
        y1=np.mean(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i][0:Points])
        y2=np.mean(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i][x_len-Points:x_len])

        x1=np.mean(XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i][0:Points])
        x2=np.mean(XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i][x_len-Points:x_len])

        #compute slope and intercept
        m=(y2-y1)/(x2-x1)
        q=y2-m*x2

        #subtract to the CPS the as computed linear background
        XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i] -= m*XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i] + q
        
    return XPS

def Aesthetics(fig):
    
    fig.update_layout(template="plotly_white")
    fig.update_layout(xaxis_title='B.E. (eV)', yaxis_title='Intensity (a.u.)')
    fig.update_yaxes(showticklabels=False,title_standoff = 30)

    fig.update_layout(yaxis = dict( tickfont = dict(size = 30)), xaxis = dict( tickfont = dict(size = 30)))
    fig.update_layout(font=dict(size=30))
    #add the black box around the graph
    fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    #add black ticks
    fig.update_xaxes(showgrid=True,ticks="inside",tickwidth=4)
    fig.update_yaxes(showgrid=True,ticks="inside",tickwidth=4)
    
    #fig.update_xaxes(autorange = "reversed")
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
    fig.update_layout(autosize=False, width=500, height=700) #w=800, h=600

# %% [markdown]
# # Main

# %%
# use this set of parameters when there is first upstream then middle
FolderTR="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/0008_120221_AQ"
names=["5s Upstream", "5s Middle","300s Upstream", "300s Middle"]
colors=['#EF553B','#636EFA', '#AB63FA', '#00CC96']
symbol=["circle","square","diamond","cross"]

# %% [markdown]
# # use this set of parameters when there is first middle then upstream
# FolderTR="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/0003_020321_AQ"
# names=["5s Middle", "5s Upstream","300s Middle", "300s Upstream"]
# colors=['#636EFA','#EF553B', '#00CC96','#AB63FA']
# symbol=["circle","square","diamond","cross"]

# %% [markdown]
# ## HOPG

# %%
FileXPS="N1sHOPG" #Name of the file with XPS Data produced by CasaXPS Sav TAB Ascii
DataPerSpectrum=209 #number of rows of each spectrum including the headers
HeaderColumns=8 #number of columns comprising the headers
NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data

#Read the XPS data and assign them to a pandas dataframe
XPSHOPG=xl.ReadXPSData(FolderTR, FileXPS)

#number of spectra composing the dataset
NumberOfSpectra=(XPSHOPG.shape[0]//NumericDataPerSpectrum)

x_len=XPSHOPG.shape[0]//NumberOfSpectra


XPSHOPG=xl.Normalize(XPSHOPG,NumberOfSpectra, NumberOfData=50)
XPSHOPG=xl.RemoveLinearBackgorund(XPSHOPG, Points=50, NumberOfSpectra=NumberOfSpectra)


fig = go.Figure()


for i in range (0, NumberOfSpectra):
    fig.add_trace(go.Scatter(mode='markers', marker_symbol=symbol[i], marker=dict(color=colors[i]), x=XPSHOPG["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i], y=XPSHOPG["CPS"].values.reshape(NumberOfSpectra,x_len)[i], name=names[i]))
    
fig.add_vline(x=399, line_dash="dash", annotation_text="N-C")
fig.add_vline(x=400, line_dash="dash",annotation_text="N-O")
fig.add_vline(x=401.5, line_dash="dash", annotation_text="N+")

fig.update_layout(title="HOPG", xaxis_title='Binding Energy (eV)', yaxis_title='CPS',xaxis_range=(404,396))
    
fig.write_html(FolderTR+"/"+"HOPG"+".html")
fig.write_image(FolderTR+"/"+"HOPG"+".svg")

fig.show()

# %% [markdown]
# ## Au

# %%
FileXPS="N1sAu" #Name of the file with XPS Data produced by CasaXPS Sav TAB Ascii
DataPerSpectrum=209 #number of rows of each spectrum including the headers
HeaderColumns=8 #number of columns comprising the headers
NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data


#Read the XPS data and assign them to a pandas dataframe
XPSAu=xl.ReadXPSData(FolderTR, FileXPS)

#number of spectra composing the dataset
NumberOfSpectra=(XPSAu.shape[0]//NumericDataPerSpectrum)

x_len=XPSAu.shape[0]//NumberOfSpectra

#XPSAu=xl.Normalize(XPSAu,NumberOfSpectra, NumberOfData=50)
XPSAu=xl.RemoveLinearBackgorund(XPSAu, Points=50, NumberOfSpectra=NumberOfSpectra)



fig = go.Figure()



for i in range (0, NumberOfSpectra):
    fig.add_trace(go.Scatter(mode='markers', marker_symbol=symbol[i], x=XPSAu["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i], y=XPSAu["CPS"].values.reshape(NumberOfSpectra,x_len)[i], name=names[i]))
    
fig.add_vline(x=399, line_dash="dash", annotation_text="N-C")
fig.add_vline(x=400, line_dash="dash",annotation_text="N-O")
fig.add_vline(x=401.5, line_dash="dash", annotation_text="N+")

fig.update_layout(title="Au", xaxis_title='Binding Energy (eV)', yaxis_title='CPS',xaxis_range=(404,396))
    
#fig.write_html(FolderTR+"/"+"Au"+".html")
#fig.write_image(FolderTR+"/"+"Au"+".svg")

fig.show()

# %% [markdown]
# ## Si

# %%
FolderTR="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/0003_020321_AQ"
FileXPS="N1sSi" #Name of the file with XPS Data produced by CasaXPS Sav TAB Ascii
DataPerSpectrum=209 #number of rows of each spectrum including the headers
HeaderColumns=8 #number of columns comprising the headers
NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data

#Read the XPS data and assign them to a pandas dataframe
XPSSi=xl.ReadXPSData(FolderTR, FileXPS, DataPerSpectrum, HeaderColumns)

#number of spectra composing the dataset
NumberOfSpectra=(XPSSi.shape[0]//NumericDataPerSpectrum)

x_len=XPSSi.shape[0]//NumberOfSpectra

XPSSi=xl.RemoveLinearBackgorund(XPSSi, Points=50, NumberOfSpectra=NumberOfSpectra)



fig = go.Figure()



for i in range (0, NumberOfSpectra):
    fig.add_trace(go.Scatter(mode='markers', marker_symbol=symbol[i], x=XPSSi["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i], y=XPSSi["CPS"].values.reshape(NumberOfSpectra,x_len)[i], name=names[i]))
    
fig.add_vline(x=399, line_dash="dash", annotation_text="N-C")
fig.add_vline(x=400, line_dash="dash",annotation_text="N-O")
fig.add_vline(x=401.5, line_dash="dash", annotation_text="N+")

fig.update_layout(title="Si", xaxis_title='Binding Energy (eV)', yaxis_title='CPS',xaxis_range=(404,396))
    
fig.write_html(FolderTR+"/"+"Si"+".html")
fig.write_image(FolderTR+"/"+"Si"+".svg")

fig.show()

# %% [markdown]
# ## PTFE

# %%
FolderTR="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/0003_020321_AQ"
FileXPS="N1sPTFE" #Name of the file with XPS Data produced by CasaXPS Sav TAB Ascii
DataPerSpectrum=209 #number of rows of each spectrum including the headers
HeaderColumns=8 #number of columns comprising the headers
NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data

#Read the XPS data and assign them to a pandas dataframe
XPSPTFE=xl.ReadXPSData(FolderTR, FileXPS)
#number of spectra composing the dataset
NumberOfSpectra=(XPSPTFE.shape[0]//NumericDataPerSpectrum)

x_len=XPSPTFE.shape[0]//NumberOfSpectra

XPSPTFE=xl.RemoveLinearBackgorund(XPSPTFE, Points=50, NumberOfSpectra=NumberOfSpectra)


fig = go.Figure()


for i in range (0, NumberOfSpectra):
    fig.add_trace(go.Scatter(mode='markers', marker_symbol=symbol[i], x=XPSPTFE["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i], y=XPSPTFE["CPS"].values.reshape(NumberOfSpectra,x_len)[i], name=names[i]))
    
fig.add_vline(x=399, line_dash="dash", annotation_text="N-C")
fig.add_vline(x=400, line_dash="dash",annotation_text="N-O")
fig.add_vline(x=401.5, line_dash="dash", annotation_text="N+")

fig.update_layout(title="PTFE", xaxis_title='Binding Energy (eV)', yaxis_title='CPS',xaxis_range=(404,396))
    
fig.write_html(FolderTR+"/"+"PTFE"+".html")
fig.write_image(FolderTR+"/"+"PTFE"+".svg")

fig.show()

# %% [markdown]
# ## Al

# %%
FolderTR="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/0003_020321_AQ"
FileXPS="N1sAl" #Name of the file with XPS Data produced by CasaXPS Sav TAB Ascii
DataPerSpectrum=209 #number of rows of each spectrum including the headers
HeaderColumns=8 #number of columns comprising the headers
NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data

#Read the XPS data and assign them to a pandas dataframe
XPSAl=xl.ReadXPSData(FolderTR, FileXPS)

#number of spectra composing the dataset
NumberOfSpectra=(XPSAl.shape[0]//NumericDataPerSpectrum)

x_len=XPSAl.shape[0]//NumberOfSpectra

XPSAl=xl.RemoveLinearBackgorund(XPSAl, Points=50, NumberOfSpectra=NumberOfSpectra)


fig = go.Figure()



for i in range (0, NumberOfSpectra):
    fig.add_trace(go.Scatter(mode='markers', marker_symbol=symbol[i], x=XPSAl["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i], y=XPSAl["CPS"].values.reshape(NumberOfSpectra,x_len)[i], name=names[i]))
    
fig.add_vline(x=399, line_dash="dash", annotation_text="N-C")
fig.add_vline(x=400, line_dash="dash",annotation_text="N-O")
fig.add_vline(x=401.5, line_dash="dash", annotation_text="N+")

fig.update_layout(title="Al", xaxis_title='Binding Energy (eV)', yaxis_title='CPS',xaxis_range=(404,396))
    
fig.write_html(FolderTR+"/"+"Al"+".html")
fig.write_image(FolderTR+"/"+"Al"+".svg")

fig.show()

# %% [markdown]
# # Comparison among substrates

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/TEMPO/"
Folders=["0021_300321_AQ","0021_300321_AQ","0021_300321_AQ","0021_300321_AQ","0021_300321_AQ"]
Peak="N1s"
#Files=["Al","Au","HOPG","PTFE","Si"]
Files=["Au","HOPG","Si"]
for i in range(len(Files)):
    Files[i] = Files[i]+Peak
    
#names=["Al","Au", "HOPG","PTFE","Si"]
names=["Au","HOPG","Si"]
titles=["5s Upstream", "5s Middle","300s Upstream", "300s Middle","600s Upstream", "600s Middle"]

symbol=["circle","cross","triangle-up","cross","triangle-up","pentagon"]
#colors=["royal blue", "black","red"]


length=169 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range (0,len(titles)):
    
    print(titles[j])
    fig = go.Figure()
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='CPS', title=titles[j]) #
    fig.update_layout(yaxis = dict( tickfont = dict(size = 22)))
    fig.update_layout(xaxis = dict( tickfont = dict(size = 22)))
    fig.update_layout(font=dict(size=22))
    

    fig.update_layout(xaxis = dict(autorange = "reversed"))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=0,t=50))
    fig.update_layout(autosize=False, width=550, height=500)
    
    fig.add_vline(x=399, line_dash="dash",annotation_text="N-C")
    fig.add_vline(x=400, line_dash="dash",annotation_text="N-O")
    


    for i in range(0,len(Files)):
        

        FolderTR=Path+Folders[i]
        DataPerSpectrum=int(DataPerSpectra[i]) #number of rows of each spectrum including the headers
        FileXPS=Files[i]
        NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
        
        
        #Read the XPS data and assign them to a pandas dataframe
        XPS=xl.ReadXPSData(FolderTR, FileXPS)
        
        #number of spectra composing the dataset
        
        NumberOfSpectra=(XPS.shape[0]//NumericDataPerSpectrum)
        XPS=xl.RemoveLinearBackgorund(XPS, Points=30, NumberOfSpectra=NumberOfSpectra)
        Mask=np.logical_and( XPS["Binding Energy"] >396, XPS["Binding Energy"] < 404)
        
       
        
        XPS=XPS[Mask]

        x_len=XPS.shape[0]//NumberOfSpectra

        fig.add_trace(go.Scatter(mode='markers',marker_symbol=symbol[i], marker=dict(size=12),
                                 x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[j],
                                 y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[j],
                                 name=names[i]))

    
    #fig.write_image(FolderTR+"/"+titles[j]+".png")
    fig.show()

# %% [markdown]
# # Graphs a.u.

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/"
Folders=["0008_120221_AQ","0008_120221_AQ","0003_020321_AQ"]
Files=["N1sSi","N1sHOPG","N1sAu"]
titles=["Si","HOPG", "Au"]

symbol=["circle","square","diamond","cross"]
names=["5s Upstream", "5s Middle","300s Upstream", "300s Middle"]

DataPerSpectra=[209,209,209] #number of rows of each spectrum including the headers
HeaderColumns=8 #number of columns comprising the headers

# %%
#For each file plot the normlized data.
#The normalization factor is RefMax
for j in range(0,len(Files)):
    
    FolderTR=Path+Folders[j]
    DataPerSpectrum=DataPerSpectra[j] #number of rows of each spectrum including the headers
    FileXPS=Files[j]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data

    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra=(XPS.shape[0]//NumericDataPerSpectrum)

    x_len=XPS.shape[0]//NumberOfSpectra

    XPSP=xl.RemoveLinearBackgorund(XPS, Points=50, NumberOfSpectra=NumberOfSpectra)


    fig = go.Figure()
    RefMax= np.max(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[2]) #values used for scaling all the specta. It is 300 s upstream
    
    for i in range (0, NumberOfSpectra):
        fig.add_trace(go.Scatter(mode='markers',marker_symbol=symbol[i], x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i], y=xl.NormalizeAU(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i],RefMax=RefMax),name=names[i]))

    fig.add_vline(x=399, line_dash="dash", annotation_text="N-C")
    fig.add_vline(x=400, line_dash="dash",annotation_text="N-O")
    fig.add_vline(x=401.5, line_dash="dash", annotation_text="N+")
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='Intensity (a.u.)')
    fig.update_layout(xaxis_range=(404,396))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=0,t=0))
    fig.update_layout(autosize=False, width=600, height=600)

    
    #fig.write_image(FolderTR+"/"+titles[j]+".png")
    fig.show()

# %% [markdown]
# # Graphs

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/"
Folders=["0021_300321_AQ","0021_300321_AQ","0021_300321_AQ","0021_300321_AQ","0021_300321_AQ"]

Peak="N1s"
Files=["Al","Au","HOPG","PTFE","Si"]
for i in range(len(Files)):
    Files[i] = Files[i]+Peak

titles=["Al","Au", "HOPG","PTFE","Si"]
symbol=["circle","square","diamond","cross","triangle-up","pentagon"]
#names=["5s Upstream", "5s Middle","300s Upstream", "300s Middle"]
names=["5s Upstream", "5s Middle","300s Upstream", "300s Middle","600s Upstream", "600s Middle"]

length=169 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range(0,len(Files)):
    
    FolderTR=Path+Folders[j]
    DataPerSpectrum=int(DataPerSpectra[j]) #number of rows of each spectrum including the headers
    FileXPS=Files[j]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra=(XPS.shape[0]//NumericDataPerSpectrum)

    x_len=XPS.shape[0]//NumberOfSpectra

    XPS=xl.RemoveLinearBackgorund(XPS, Points=30, NumberOfSpectra=NumberOfSpectra)

    print(titles[j])

    fig = go.Figure()
    
    for i in range (0, NumberOfSpectra):
        fig.add_trace(go.Scatter(mode='markers',marker_symbol=symbol[i],
                                 x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
                                 y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i],
                                 name=names[i]))

   
    
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='Intensity (a.u.)',title=titles[j])
    if (Peak=="N1s"):
        fig.update_layout(xaxis_range=(404,396))
        fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
        fig.add_vline(x=399, line_dash="dash", annotation_text="N-C")
        fig.add_vline(x=400, line_dash="dash",annotation_text="N-O")
        fig.add_vline(x=401.5, line_dash="dash", annotation_text="N+")
    if (Peak == "C1s"):
        fig.update_layout(xaxis_range=(295,281))
        fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="left",x=0.01))
        
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=0,t=30))
    fig.update_layout(autosize=False, width=500, height=500)

    
    #fig.write_image(FolderTR+"/"+titles[j]+Peak+".png")
    fig.show()

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/"
Folders=["0008_120221_AQ","0016_240321_AQ"]
Files=["N1sAu","AuN1s"]
titles=["12_02_21","24_03_21"]

symbol=["circle","square","diamond","cross"]
names=["5s Upstream", "5s Middle","300s Upstream", "300s Middle"]

DataPerSpectra=[209,169] #number of rows of each spectrum including the headers
HeaderColumns=8 #number of columns comprising the headers

# %%
#For each file plot the normlized data.
#The normalization factor is RefMax
for j in range(0,len(Files)):
    
    FolderTR=Path+Folders[j]
    DataPerSpectrum=DataPerSpectra[j] #number of rows of each spectrum including the headers
    FileXPS=Files[j]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra=(XPS.shape[0]//NumericDataPerSpectrum)

    x_len=XPS.shape[0]//NumberOfSpectra

    XPSP=xl.RemoveLinearBackgorund(XPS, Points=50, NumberOfSpectra=NumberOfSpectra)


    fig = go.Figure()
    RefMax= np.max(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[2]) #values used for scaling all the specta. It is 300 s upstream
    
    for i in range (0, NumberOfSpectra):
        fig.add_trace(go.Scatter(mode='markers',marker_symbol=symbol[i], x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i], y=xl.NormalizeAU(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i],RefMax=RefMax),name=names[i]))

    fig.add_vline(x=399, line_dash="dash", annotation_text="N-C")
    fig.add_vline(x=400, line_dash="dash",annotation_text="N-O")
    fig.add_vline(x=401.5, line_dash="dash", annotation_text="N+")
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='Intensity (a.u.)')
    fig.update_layout(xaxis_range=(404,396))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=0,t=0))
    fig.update_layout(autosize=False, width=600, height=600)

    
    #fig.write_image(FolderTR+"/"+titles[j]+".png")
    fig.show()

# %% [markdown]
# # Wide

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/"
Folders=["0021_300321_AQ","0021_300321_AQ","0021_300321_AQ","0021_300321_AQ","0021_300321_AQ"]

Peak="Wide"
Files=["Al","Au","HOPG","PTFE","Si"]
titles=Files
for i in range(len(Files)):
    Files[i] = Files[i]+Peak

titles=["Al","Au", "HOPG","PTFE","Si"]
symbol=["circle","square","diamond","cross","triangle-up","pentagon"]
#names=["5s Upstream", "5s Middle","300s Upstream", "300s Middle"]
names=["5s Upstream", "5s Middle","300s Upstream", "300s Middle","600s Upstream", "600s Middle"]

length=1214 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range(0,len(Files)):
    
    
    FolderTR=Path+Folders[j]
    DataPerSpectrum=int(DataPerSpectra[j]) #number of rows of each spectrum including the headers
    FileXPS=Files[j]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra=(XPS.shape[0]//NumericDataPerSpectrum)

    x_len=XPS.shape[0]//NumberOfSpectra
     
    fig = go.Figure()
    
   
    offset=0
    for i in range (0, NumberOfSpectra):
        if (i==0):
            offset=0
        else:
            offset += np.abs(np.max(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i-1])
                           -np.min(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i-1]))
            
        fig.add_trace(go.Scatter(x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
                                 y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i]+offset,
                                 name=names[i]))
        

    fig.add_vline(x=285, line_dash="dash", annotation_text="C", line_width=1)
    fig.add_vline(x=400, line_dash="dash",annotation_text="N",line_width=1)
    fig.add_vline(x=532, line_dash="dash", annotation_text="O",line_width=1)
    
    
    
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='Intensity (a.u.)',title=titles[j])
    #fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="left",x=0.01))
    #fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(xaxis_range=(800,0))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=0,t=30))
    fig.update_layout(autosize=False, width=500, height=500)

    
    #fig.write_image(FolderTR+"/"+titles[j]+Peak+".png")
    fig.show()

# %% [markdown]
# # Wide subplots

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/"
Folders=["0021_300321_AQ","0021_300321_AQ","0021_300321_AQ","0021_300321_AQ","0021_300321_AQ"]

Peak="Wide"
Files=["Al","Au","HOPG","PTFE","Si"]
titles=Files
for i in range(len(Files)):
    Files[i] = Files[i]+Peak

titles=["Al","Au", "HOPG","PTFE","Si"]
symbol=["circle","square","diamond","cross","triangle-up","pentagon"]
#names=["5s Upstream", "5s Middle","300s Upstream", "300s Middle"]
names=["5s Upstream", "5s Middle","300s Upstream", "300s Middle","600s Upstream", "600s Middle"]

length=1214 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
fig = make_subplots(rows=1, cols=3,shared_yaxes=True,shared_xaxes=True)

for j in range(0,len(Files)):
    
    
    FolderTR=Path+Folders[j]
    DataPerSpectrum=int(DataPerSpectra[j]) #number of rows of each spectrum including the headers
    FileXPS=Files[j]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra=(XPS.shape[0]//NumericDataPerSpectrum)

    x_len=XPS.shape[0]//NumberOfSpectra

    
   
    offset=0
    for i in range (0, NumberOfSpectra):
        if (i==0):
            offset=0
        else:
            offset += np.abs(np.max(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i-1])
                           -np.min(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i-1]))
            
        fig.add_trace(go.Scatter(x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
                                 y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i]+offset,
                                 name=names[i]),row=1, col=1+j)
        

    fig.add_vline(x=285, line_dash="dash", annotation_text="C", line_width=1)
    fig.add_vline(x=400, line_dash="dash",annotation_text="N",line_width=1)
    fig.add_vline(x=532, line_dash="dash", annotation_text="O",line_width=1)
    
    
    
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='Intensity (a.u.)',title=titles[j])
    #fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="left",x=0.01))
    #fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(xaxis_range=(800,0))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=0,t=30))
    #fig.update_layout(autosize=False, width=500, height=500)

    
    #fig.write_image(FolderTR+"/"+titles[j]+Peak+".png")
    fig.show()

# %% [markdown]
# # Several spectra

# %% [markdown]
# ## 5s

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/TEMPO/"
Folders=["0006_070521_AQ","0006_070521_AQ","0006_070521_AQ"]
Peak="N1s"

Files=["Au","HOPG","Si"]
for i in range(len(Files)):
    Files[i] = Files[i]+Peak
    
#names=["Al","Au", "HOPG","PTFE","Si"]
names=["Au","HOPG","Si"]
titles=["5s Upstream", "5s Middle"]

symbol=["circle","square","diamond","cross","triangle-up","pentagon"]


length=169 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range (0,len(titles)):
    
    print(titles[j])
    
    fig = go.Figure()
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='CPS', title=titles[j])
    fig.update_layout(xaxis_range=(404,396))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=0,t=30))
    fig.update_layout(autosize=False, width=500, height=500)
    
    fig.add_vline(x=399, line_dash="dash", annotation_text="N-C")
    fig.add_vline(x=400, line_dash="dash",annotation_text="N-O")
    #fig.add_vline(x=401.5, line_dash="dash", annotation_text="N+")
    


    for i in range(0,len(Files)):
        

        FolderTR=Path+Folders[i]
        DataPerSpectrum=int(DataPerSpectra[i]) #number of rows of each spectrum including the headers
        FileXPS=Files[i]
        NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
        
        
        #Read the XPS data and assign them to a pandas dataframe
        XPS=xl.ReadXPSData(FolderTR, FileXPS, DataPerSpectrum, HeaderColumns)
        
        #number of spectra composing the dataset
        NumberOfSpectra=(XPS.shape[0]//NumericDataPerSpectrum)

        x_len=XPS.shape[0]//NumberOfSpectra
        
        XPS=xl.RemoveLinearBackgorund(XPS, Points=30, NumberOfSpectra=NumberOfSpectra)
        
        for k in range (j*3,(j+1)*3):
        

            fig.add_trace(go.Scatter(mode='markers',marker_symbol=symbol[i],
                                     x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[k],
                                     y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[k],
                                     name=names[i]))

    
    fig.write_image(FolderTR+"/"+titles[j]+".png")
    fig.show()

# %% [markdown]
# ## 600 s

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/TEMPO/"
Folders=["0006_070521_AQ","0006_070521_AQ","0006_070521_AQ"]
Peak="N1s"

Files=["Au","HOPG","Si"]
for i in range(len(Files)):
    Files[i] = Files[i]+Peak+"_600s"
    
#names=["Al","Au", "HOPG","PTFE","Si"]
names=["Au","HOPG","Si"]
titles=["600s Upstream", "600s Middle"]

symbol=["circle","square","diamond","cross","triangle-up","pentagon"]


length=169 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range (0,len(titles)):
    
    print(titles[j])
    
    fig = go.Figure()
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='CPS', title=titles[j])
    fig.update_layout(xaxis_range=(404,396))
    fig.update_layout(yaxis = dict( tickfont = dict(size = 22)))
    fig.update_layout(xaxis = dict( tickfont = dict(size = 22)))
    fig.update_layout(font=dict(size=22))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=0,t=50))
    fig.update_layout(autosize=False, width=600, height=500)
    
    fig.add_vline(x=399, line_dash="dash", annotation_text="N-C")
    fig.add_vline(x=400, line_dash="dash",annotation_text="N-O")
    


    for i in range(0,len(Files)):
        

        FolderTR=Path+Folders[i]
        DataPerSpectrum=int(DataPerSpectra[i]) #number of rows of each spectrum including the headers
        FileXPS=Files[i]
        NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
        
        
        #Read the XPS data and assign them to a pandas dataframe
        XPS=xl.ReadXPSData(FolderTR, FileXPS)
        
        #number of spectra composing the dataset
        NumberOfSpectra=(XPS.shape[0]//NumericDataPerSpectrum)

        x_len=XPS.shape[0]//NumberOfSpectra
        
        XPS=xl.RemoveLinearBackgorund(XPS, Points=30, NumberOfSpectra=NumberOfSpectra)
        
        for k in range (j*3,(j+1)*3):
        

            fig.add_trace(go.Scatter(mode='markers',marker_symbol=symbol[i], marker=dict(size=8),
                                     x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[k],
                                     y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[k],
                                     name=names[i]))

    
    #fig.write_image(FolderTR+"/"+titles[j]+".png")
    fig.show()

# %% [markdown]
# # Poster

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/TEMPO/"
Folders=["0021_300321_AQ","0021_300321_AQ","0021_300321_AQ"]
Peak="N1s"

Files=["Au","HOPG","Si"]
for i in range(len(Files)):
    Files[i] = Files[i]+Peak
    
#names=["Al","Au", "HOPG","PTFE","Si"]
names=["Au","HOPG","Si"]
titles=["5s Upstream", "5s Middle","300s Upstream", "300s Middle","600s Upstream", "600s Middle"]

symbol=["circle","cross","triangle-up"]
colors=["blue", "black","red"]


length=169 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range (0,len(titles)):
    
    print(titles[j])
    fig = go.Figure()
    fig.update_layout(template="plotly_white")
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='CPS')
    fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
    fig.update_layout(font=dict(size=23))
    #add the black box around the graph
    fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    #add black ticks
    fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
    fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
    
    fig.update_layout(xaxis = dict(autorange = "reversed"))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
    fig.update_layout(autosize=False, width=550, height=500)
    
    fig.add_vline(x=399, line_dash="dash",annotation_text="N-C")
    fig.add_vline(x=400, line_dash="dash",annotation_text="N-O")
    fig.add_vline(x=401.5, line_dash="dash",annotation_text="N+")
    


    for i in range(0,len(Files)):
        

        FolderTR=Path+Folders[i]
        DataPerSpectrum=int(DataPerSpectra[i]) #number of rows of each spectrum including the headers
        FileXPS=Files[i]
        NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
       
        
        #Read the XPS data and assign them to a pandas dataframe
        XPS=xl.ReadXPSData(FolderTR, FileXPS)
        
        #number of spectra composing the dataset
        NumberOfSpectra=(XPS.shape[0]//NumericDataPerSpectrum)

        XPS=xl.RemoveLinearBackgorund(XPS, Points=30, NumberOfSpectra=NumberOfSpectra)
        
        Mask=np.logical_and( XPS["Binding Energy"] >396, XPS["Binding Energy"] < 404)
        XPS=XPS[Mask]

        x_len=XPS.shape[0]//NumberOfSpectra

        fig.add_trace(go.Scatter(mode='markers',marker_symbol=symbol[i], marker=dict(size=12, color=colors[i]),
                                 x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[j],
                                 y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[j],
                                 name=names[i]))

    
    fig.write_image(FolderTR+"/"+titles[j]+"_Paper"+".svg")
    fig.show()

# %% [markdown]
# # Annealing
#
# TEMPO on HOPG 5s upstream 9.74 Pa - 13/05/21

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/TEMPO/"
Folders=['0007_300322_AQ']  #["0004_040621_AQ"]
Files=["N1s_calibrated"]  

names=["25 °C", "50 °C UHV","50 °C Air"]
titles=["annealing"]

symbol=["circle","cross","diamond"]
colors=["blue", "red", "green"]

length=168 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range(0,len(Files)):
    
    FolderTR=Path+Folders[j]
    DataPerSpectrum=DataPerSpectra[j] #number of rows of each spectrum including the headers
    FileXPS=Files[j]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra=int(XPS.shape[0]//NumericDataPerSpectrum)

    XPS=xl.RemoveLinearBackgorund(XPS, Points=50, NumberOfSpectra=NumberOfSpectra)

    Mask=np.logical_and( XPS["Binding Energy"] >396, XPS["Binding Energy"] < 404)
    XPS=XPS[Mask]
    Mask=XPS["CPS"]>-5
    XPS=XPS[Mask]
    x_len=XPS.shape[0]//NumberOfSpectra
    
    print(x_len)
    print(NumberOfSpectra)
    
    print(len(XPS["Binding Energy"].values))
    
    
    fig = go.Figure()
    fig.update_layout(template="plotly_white")
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='CPS')
    fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
    fig.update_layout(font=dict(size=23))
    #add the black box around the graph
    fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    #add black ticks
    fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
    fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
    
    fig.update_layout(xaxis = dict(autorange = "reversed"))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
    fig.update_layout(autosize=False, width=550, height=500)
    
    fig.add_vline(x=399, line_dash="dash",annotation_text="N-C")
    fig.add_vline(x=400, line_dash="dash",annotation_text="N-O")
    fig.add_vline(x=401.5, line_dash="dash",annotation_text="N+")
    
    for i in range (0, NumberOfSpectra):
        fig.add_trace(go.Scatter(mode='markers',marker_symbol=symbol[i], marker=dict(size=12, color=colors[i]),
                                 x=XPS["Binding Energy"].values[0:168].reshape(NumberOfSpectra,x_len)[i],
                                 y=XPS["CPS"].values[0:168].reshape(NumberOfSpectra,x_len)[i],
                                 name=names[i]))
    
fig.write_image(FolderTR+"/"+titles[j]+".png")
fig.write_image(FolderTR+"/"+titles[j]+".svg")
fig.show()

# %% [markdown]
# # Non-polymerised TEMPO

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/TEMPO/"
Folders=['0003_090522_AQ']  #["0004_040621_AQ"]
Files=["N1s_NonPolymerised"]  

names=["5 min", "1 min","pristine"]
titles=["Non-polymerised"]

dashes=["dashdot","dash","dot"]
colors=["blue", "red", "green"]

length=168 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range(0,len(Files)):
    
    FolderTR=Path+Folders[j]
    DataPerSpectrum=DataPerSpectra[j] #number of rows of each spectrum including the headers
    FileXPS=Files[j]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra=int(XPS.shape[0]//NumericDataPerSpectrum)
    x_len=XPS.shape[0]//NumberOfSpectra
    
    fig = go.Figure()   
    
    for i in range (0, NumberOfSpectra):
        fig.add_trace(go.Scatter(
           line = dict(color=colors[i], dash=dashes[i]),
                                 x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
                                 y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i]-np.min(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i]),
                                 name=names[i]))
    
fig.update_layout(template="plotly_white")
fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='CPS')
fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
fig.update_layout(font=dict(size=23))
#add the black box around the graph
fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
#add black ticks
fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
#plot dimensions
fig.update_layout(xaxis = dict(autorange = "reversed"))
fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
fig.update_layout(autosize=False, width=550, height=500)
#save
fig.write_image(FolderTR+"/"+titles[j]+".png")
fig.write_image(FolderTR+"/"+titles[j]+".svg")
fig.show()

# %% [markdown]
# # Paper

# %% [markdown]
# ## Fitted Data
# 30/03/21

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/TEMPO/"
Folders=["0021_300321_AQ","0021_300321_AQ"]
Files=["N1sFitted_Upstream", "N1sFitted_Middle"]

length=169 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

colors=["gray", "blue", "red", "black", "orange"]
Letters=["a)","b)","c)","d)","e)","f)","g)","h)","i)", "l)"]
Times=["5 s"," 5 s","5 s","300 s","300 s","300 s","600 s","600 s","600 s"]

#columns of the file to read
Columns=["K.E.", "Counts", "N-C K.E.", "N-O K.E.", "N+ K.E.", "Background", "Envelope",
"Binding Energy", "CPS", "N-C", "N-O", "N+", "Background CPS", "Envelope CPS"]

# %%
 for i in range(0,len(Files)):
        

    FolderTR=Path+Folders[i]
    DataPerSpectrum=int(DataPerSpectra[i]) #number of rows of each spectrum including the headers
    FileXPS=Files[i]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    
        
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    NumberOfSpectra=(XPS.shape[0]//NumericDataPerSpectrum)
    Mask=np.logical_and( XPS["Binding Energy"] >396, XPS["Binding Energy"] < 404)
    XPS=XPS[Mask]
    x_len=(XPS.shape[0]//NumberOfSpectra)
        
    fig = make_subplots(rows=3, cols=3,subplot_titles=("HOPG", "Au(111)", "SiO<sub>2"),
                        shared_xaxes=True, shared_yaxes=True,
                        vertical_spacing=0.05)
    
    
    #white background
    fig.update_layout(template="plotly_white")
    #x-axis
    fig.update_xaxes(autorange = "reversed")
    fig.update_xaxes(title='Binding Energy (eV)', row=3, col=1)
    fig.update_xaxes(title='Binding Energy (eV)', row=3, col=2)
    fig.update_xaxes(title='Binding Energy (eV)', row=3, col=3)
    #y-axis
    fig.update_yaxes(title='CPS', row=1, col=1)
    fig.update_yaxes(title='CPS', row=2, col=1)
    fig.update_yaxes(title='CPS', row=3, col=1)
    #font size
    fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
    fig.update_layout(font=dict(size=23))
    fig.update_annotations(font_size=30)     #dimensions of the titles
    #add the black box around the graph
    fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    #add black ticks
    fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
    fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
    #fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.10))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=50))
    fig.update_layout(autosize=False, width=1400, height=1000)

    j=0
    
    print (Files[i])
    for k in range (0, 3):
        for l in range(0,3):

            fig.add_trace(go.Scatter(mode='markers', marker=dict(size=12, color=colors[0],opacity=0.5),
                                        x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[j],
                                        y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[j]-
                                         XPS["Background CPS"].values.reshape(NumberOfSpectra,x_len)[j],
                                         name="Data"),
                                          col=1+l, row=1+k)
            fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[1],dash='dot'),
                                        x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[j],
                                        y=XPS["N-C"].values.reshape(NumberOfSpectra,x_len)[j]-
                                         XPS["Background CPS"].values.reshape(NumberOfSpectra,x_len)[j],
                                        name="N-C"),
                                         col=1+l, row=1+k)
            fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[2],dash='dot'),
                                        x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[j],
                                        y=XPS["N-O"].values.reshape(NumberOfSpectra,x_len)[j]-
                                         XPS["Background CPS"].values.reshape(NumberOfSpectra,x_len)[j],
                                        name="N-O"),
                                         col=1+l, row=1+k)
            fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[3],dash='dot'),
                                        x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[j],
                                        y=XPS["N+"].values.reshape(NumberOfSpectra,x_len)[j]-
                                         XPS["Background CPS"].values.reshape(NumberOfSpectra,x_len)[j],
                                        name="N+"),
                                         col=1+l, row=1+k)
            fig.add_trace(go.Scatter(mode='lines', line=dict(width=5, color=colors[4],dash="dash"),
                                        x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[j],
                                        y=XPS["N-C"].values.reshape(NumberOfSpectra,x_len)[j]+
                                        XPS["N-O"].values.reshape(NumberOfSpectra,x_len)[j]+
                                        XPS["N+"].values.reshape(NumberOfSpectra,x_len)[j]-
                                         3*XPS["Background CPS"].values.reshape(NumberOfSpectra,x_len)[j],
                                        name="Envelope"),
                                         col=1+l, row=1+k)
            
            fig.add_annotation(xref="x domain", yref="y domain",x=0.05, y=0.95, text=Letters[j], showarrow=False, yshift=10, col=1+l, row=1+k)
            fig.add_annotation(xref="x domain", yref="y domain",x=0.95, y=0.95, text=Times[j], showarrow=False, yshift=10, col=1+l, row=1+k)

            j=j+1
    names = set()
    fig.for_each_trace(
            lambda trace:
                trace.update(showlegend=False)
                if (trace.name in names) else names.add(trace.name))
    #fig.write_image(FolderTR+"/"+Files[i]+".svg")
    #fig.write_image(FolderTR+"/"+Files[i]+".pdf")
    fig.show()

# %% [markdown]
# ## Overlapped Spectra

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/TEMPO/"
Folders=["0021_300321_AQ","0021_300321_AQ","0021_300321_AQ","0021_300321_AQ","0021_300321_AQ"]
Peak="N1s"

Files=["Au","HOPG","Si","PTFE","Al"]
for i in range(len(Files)):
    Files[i] = Files[i]+Peak
 
names=["Au","HOPG","Si","PTFE","Al"]
titles=["5s Upstream", "5s Middle","300s Upstream", "300s Middle","600s Upstream", "600s Middle"]

symbol=["circle","cross","triangle-up","square","diamond"]
colors=["blue", "black","red", "orange","green"]


length=169 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range (0,len(titles)):
    
    print(titles[j])
    fig = go.Figure()
    fig.update_layout(template="plotly_white")
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='CPS')
    fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
    fig.update_layout(font=dict(size=23))
    #add the black box around the graph
    fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    #add black ticks
    fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
    fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
    
    fig.update_layout(xaxis = dict(autorange = "reversed"))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
    fig.update_layout(autosize=False, width=550, height=500)
    
    fig.add_vline(x=399, line_dash="dash",annotation_text="N-C")
    fig.add_vline(x=400, line_dash="dash",annotation_text="N-O")
    fig.add_vline(x=401.5, line_dash="dash",annotation_text="N+")
    


    for i in range(0,len(Files)):
        

        FolderTR=Path+Folders[i]
        DataPerSpectrum=int(DataPerSpectra[i]) #number of rows of each spectrum including the headers
        FileXPS=Files[i]
        NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
        
        
        #Read the XPS data and assign them to a pandas dataframe
        XPS=xl.ReadXPSData(FolderTR, FileXPS)
        
        #number of spectra composing the dataset
        NumberOfSpectra=(XPS.shape[0]//NumericDataPerSpectrum)

        XPS=xl.RemoveLinearBackgorund(XPS, Points=30, NumberOfSpectra=NumberOfSpectra)
        
        Mask=np.logical_and( XPS["Binding Energy"] >396, XPS["Binding Energy"] < 404)
        XPS=XPS[Mask]

        x_len=XPS.shape[0]//NumberOfSpectra

        fig.add_trace(go.Scatter(mode='markers',marker_symbol=symbol[i], marker=dict(size=12, color=colors[i], opacity=0.6),
                                 x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[j],
                                 y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[j],
                                 name=names[i]))

    
    fig.write_image(FolderTR+"/"+titles[j]+"_Abstract_PTFE_Al"+".svg")
    fig.show()

# %% [markdown]
# ## Wide Spectra

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/TEMPO/"
Folders=["0021_300321_AQ","0021_300321_AQ","0021_300321_AQ","0021_300321_AQ","0021_300321_AQ"]

Peak="Wide"
Files=["Au","HOPG","Si"]
titles=Files
for i in range(len(Files)):
    Files[i] = Files[i]+Peak

titles=["Au", "HOPG","Si"]
symbol=["circle","square","cross", "diamond","triangle-up","pentagon"]
#names=["5s Upstream", "5s Middle","300s Upstream", "300s Middle"]
Names=["5 s","300 s", "600 s"]
colors=["blue", "black","red"]
Letters=["a)","b)","c)","d)","e)","f)","g)","h)","i)", "l)"]



length=1214 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
fig = make_subplots(rows=3, cols=2,
                    vertical_spacing=0.05,horizontal_spacing=0.05,
                    shared_xaxes=True, shared_yaxes=True,
                    subplot_titles=("Glow", "Afterglow"))

#white background
fig.update_layout(template="plotly_white")
#x-axis
fig.update_xaxes(autorange = "reversed")
#fig.update_xaxes(domain=[0.7,0.0])
#
fig.update_xaxes(title='Binding Energy (eV)', row=3, col=1)
fig.update_xaxes(title='Binding Energy (eV)', row=3, col=2)
fig.update_xaxes(title='Binding Energy (eV)', row=3, col=3)
#y-axis
fig.update_yaxes(title='CPS (a.u.)', row=1, col=1)
fig.update_yaxes(title='CPS (a.u.)', row=2, col=1)
fig.update_yaxes(title='CPS (a.u.)', row=3, col=1)
#font size
fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
fig.update_layout(font=dict(size=23))
fig.update_annotations(font_size=30)     #dimensions of the titles
#add the black box around the graph
fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
#add black ticks
fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
fig.update_layout(legend=dict(yanchor="top",y=0.95,xanchor="right",x=0.115))
fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=50))
fig.update_layout(autosize=False, width=1100, height=1000)
fig.update_layout(yaxis = dict(exponentformat = 'B'), row=2, col=1)

#letters for the panels
s=0
for n in range(0,3):
    for m in range(0,2):
    
        fig.add_annotation(xref="x domain", yref="y domain",x=0.03, y=0.95,text=Letters[s],
                           showarrow=False, yshift=10, col=1+m, row=1+n)
        s=s+1


for j in range(0,len(Files)):
    
    
    FolderTR=Path+Folders[j]
    DataPerSpectrum=int(DataPerSpectra[j]) #number of rows of each spectrum including the headers
    FileXPS=Files[j]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra=(XPS.shape[0]//NumericDataPerSpectrum)
    
    Mask=np.logical_and(XPS["Binding Energy"] >0, XPS["Binding Energy"] < 700)
    XPS=XPS[Mask]

    x_len=XPS.shape[0]//NumberOfSpectra

    for i in range (0, NumberOfSpectra):
            
        if (i%2==0):
            
            fig.add_trace(go.Scatter(line=dict(color=colors[i//2]),
                                     x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
                                     y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i],
                                     name=Names[i//2]),row=1+j, col=1+0)
            
        if (i%2==1):
            
            fig.add_trace(go.Scatter(line=dict(color=colors[i//2]),
                                     x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
                                     y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i],
                                     name=Names[i//2]),row=1+j, col=1+1)
            
    names = set()
    fig.for_each_trace(
            lambda trace:
                trace.update(showlegend=False)
                if (trace.name in names) else names.add(trace.name))

#Peaks labels
fig.add_vline(x=400, line_dash="dash", line=dict(width=1), annotation_text="N<br>1s", annotation=dict(font_size=18))
fig.add_vline(x=532, line_dash="dash", line=dict(width=1), annotation_text="O<br>1s", annotation=dict(font_size=18))
fig.add_vline(x=285, line_dash="dash", line=dict(width=1), annotation_text="C<br>1s", annotation=dict(font_size=18))
fig.add_vline(x=84, line_dash="dash", line=dict(width=1), annotation_text="Au<br>4f<sub>7/2", annotation=dict(font_size=18), row=1)
fig.add_vline(x=99.4, line_dash="dash", line=dict(width=1), annotation_text="Si<br>2p", annotation=dict(font_size=18), row=3)


        
#fig.write_image(FolderTR+"/"+"Wide_Paper"+".svg")
#fig.write_image(FolderTR+"/"+"Wide_Paper"+".pdf")
fig.show()

# %% [markdown]
# # Overlapped spectra + PTFE

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/TEMPO/"
Folders=["0021_300321_AQ","0021_300321_AQ","0021_300321_AQ","0021_300321_AQ"]
Peak="N1s"

Files=["Au","HOPG","Si", "PTFE"]
for i in range(len(Files)):
    Files[i] = Files[i]+Peak
    

Names=["Au(111)","HOPG","SiO<sub>2", "PTFE"]
titles=["5s Glow", "5s Afterglow","300s Glow", "300s Afterglow","600s Glow", "600s Afterglow"]

symbol=["circle","cross","triangle-up", "diamond"]
colors=["blue", "black","red", "orange"]


length=169 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
fig = make_subplots(rows=3, cols=2,subplot_titles=titles,
                        shared_xaxes=True, shared_yaxes=True,
                        vertical_spacing=0.05)
    
    
#white background
fig.update_layout(template="plotly_white")
#x-axis
fig.update_xaxes(autorange = "reversed")
fig.update_xaxes(title='Binding Energy (eV)', row=3, col=1)
fig.update_xaxes(title='Binding Energy (eV)', row=3, col=2)
fig.update_xaxes(title='Binding Energy (eV)', row=3, col=3)
#y-axis
fig.update_yaxes(title='CPS', row=1, col=1)
fig.update_yaxes(title='CPS', row=2, col=1)
fig.update_yaxes(title='CPS', row=3, col=1)
#font size
fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
fig.update_layout(font=dict(size=23))
fig.update_annotations(font_size=30)     #dimensions of the titles
#add the black box around the graph
fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
#add black ticks
fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
#fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.10))
fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=50))
fig.update_layout(autosize=False, width=1000, height=1300)

for i in range(0,len(Files)):
        

    FolderTR=Path+Folders[i]
    DataPerSpectrum=int(DataPerSpectra[i]) #number of rows of each spectrum including the headers
    FileXPS=Files[i]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
   

            #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    NumberOfSpectra=(XPS.shape[0]//NumericDataPerSpectrum)
    XPS=xl.RemoveLinearBackgorund(XPS, Points=30, NumberOfSpectra=NumberOfSpectra)
    Mask=np.logical_and( XPS["Binding Energy"] >396, XPS["Binding Energy"] < 404)
    XPS=XPS[Mask]
    x_len=(XPS.shape[0]//NumberOfSpectra)
    
    j=0
            
    for k in range (0, 3):
        for l in range(0,2):

            fig.add_trace(go.Scatter(mode='markers',marker_symbol=symbol[i], marker=dict(size=10, color=colors[i],opacity=0.8),
                                 x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[j],
                                 y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[j],
                                 name=Names[i]),
                            col=1+l, row=1+k)
            j=j+1
            
            #fig.add_annotation(xref="x domain", yref="y domain",x=0.05, y=0.95, text=Letters[j], showarrow=False, yshift=10, col=1+l, row=1+k)
            
    names = set()
    fig.for_each_trace(
            lambda trace:
                trace.update(showlegend=False)
                if (trace.name in names) else names.add(trace.name))
#fig.write_image(FolderTR+"/"+"Overlapped_plus_PTFE"+".svg")
#fig.write_image(FolderTR+"/"+"Overlapped_plus_PTFE"+".pdf")
fig.show()

# %% [markdown]
# # Antiviral XPS

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/Antiviral/"
Folders=['0010_210122_AQ']
Files=["C1s.txt"]  

names=["PFC", "Acrylic acid","Acrylic acid on PFC"]
titles=["Antiviral XPS"]

symbol=["circle","cross","diamond"]
colors=["blue", "red", "green"]

length=239 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

for j in range(0,len(Files)):
    
    FolderTR=Path+Folders[j]
    DataPerSpectrum=DataPerSpectra[j] #number of rows of each spectrum including the headers
    FileXPS=Files[j]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra=int(XPS.shape[0]//NumericDataPerSpectrum)

    #XPS=xl.RemoveLinearBackgorund(XPS, Points=10, NumberOfSpectra=NumberOfSpectra)
    x_len=XPS.shape[0]//NumberOfSpectra
    
    
    
    
    fig = go.Figure()
    fig.update_layout(template="plotly_white")
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='CPS')
    fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
    fig.update_layout(font=dict(size=23))
    #add the black box around the graph
    fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    #add black ticks
    fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
    fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
    
    fig.update_layout(xaxis = dict(range = (297,280)))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.62))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
    fig.update_layout(autosize=False, width=550, height=500)
    
    
    
    for i in range (0, NumberOfSpectra):
        fig.add_trace(go.Scatter(mode='markers',marker_symbol=symbol[i], marker=dict(size=12, color=colors[i]),opacity=0.6,
                                 x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
                                 y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i],
                                 name=names[i]))
    
FolderThesis="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Bibliography/Antiviral figures"
fig.write_image(FolderTR+"/"+titles[j]+".png")
fig.write_image(FolderTR+"/"+titles[j]+".svg")
fig.write_image(FolderThesis+"/"+titles[j]+".png")
fig.write_image(FolderThesis+"/"+titles[j]+".svg")
fig.show()

# %% [markdown]
# # OCCA Examples

# %% [markdown]
# ## C1s

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/TEMPO/"
Folders=["0004_090622_AQ"]
Files=["C1s_Fit"]

length=239 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

colors=["gray", "blue", "red", "black","green","violet","brown","orange"]

#columns of the file to read
XPS=pd.read_table(Path+Folders[0]+"/"+Files[0], skiprows=lambda x: x%DataPerSpectra<HeaderColumns-1, header=0)

# %%
fig = go.Figure()
fig.update_layout(template="plotly_white")
fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='Intrnsity (CPS)')
fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
fig.update_layout(font=dict(size=23))
#add the black box around the graph
fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
#add black ticks
fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
    
fig.update_layout(xaxis =dict(range=[297,282]))
fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
fig.update_layout(autosize=False, width=550, height=500)
# do not use the k format for the thousands
fig.update_layout(yaxis = dict(exponentformat = 'none'))
# tick every 2eV
fig.update_layout( xaxis = dict(tickmode = 'linear',tick0 = 0,dtick = 2))


fig.add_trace(go.Scatter(mode='markers', marker=dict(size=12, color=colors[0],opacity=0.5),
                                 x=XPS["B.E."].values,
                                 y=XPS["CPS"].values-XPS["Background CPS"].values))

fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[1],dash='dot'),
                                 x=XPS["B.E."].values,
                                 y=XPS["C-F2.1"].values-XPS["Background CPS"].values))

fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[2],dash='dot'),
                                 x=XPS["B.E."].values,
                                 y=XPS["C-C/H.1"].values-XPS["Background CPS"].values))

fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[3],dash='dot'),
                                 x=XPS["B.E."].values,
                                 y=XPS["C-N.1"].values-XPS["Background CPS"].values))


fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[4],dash='dot'),
                                 x=XPS["B.E."].values,
                                 y=XPS["C-O.1"].values-XPS["Background CPS"].values))

fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[5],dash='dot'),
                                 x=XPS["B.E."].values,
                                 y=XPS["C=O.1"].values-XPS["Background CPS"].values))

fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[6],dash='dot'),
                                 x=XPS["B.E."].values,
                                 y=XPS["O-C=O.1"].values-XPS["Background CPS"].values))


fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[7],dash='dash'),
                                 x=XPS["B.E."].values,
                                 y=XPS["Envelope CPS"].values-XPS["Background CPS"].values))

fig.update_layout(showlegend=False)

fig.show()

fig.write_image(Path+Folders[0]+"/"+"OCCA_Carbon1s"+".svg")
fig.write_image("C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Publications/OCCA Perspective"+"/"+"Carbon1s"+".svg")
fig.write_html("C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Publications/OCCA Perspective"+"/"+"Carbon1s"+".html")

# %% [markdown]
# ## N 1s

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/TEMPO/"

Folders=["0021_300321_AQ"]
Files=["N1s_Fitted_Upstream_OCCA.txt"]


length=169 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

colors=["gray", "blue", "red", "black","green","violet","brown","orange"]

#columns of the file to read
XPS=pd.read_table(Path+Folders[0]+"/"+Files[0], skiprows=lambda x: x%DataPerSpectra<HeaderColumns-1, header=0)

# %%
XPS

# %%
fig = go.Figure()
fig.update_layout(template="plotly_white")
fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='CPS')
fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
fig.update_layout(font=dict(size=23))
#add the black box around the graph
fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
#add black ticks
fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
    
fig.update_layout(xaxis =dict(range=[405,395]))
fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
fig.update_layout(autosize=False, width=550, height=500)
# do not use the k format for the thousands
fig.update_layout(yaxis = dict(exponentformat = 'none'))
# tick every 2eV
fig.update_layout( xaxis = dict(tickmode = 'linear',tick0 = 0,dtick = 2))



fig.add_trace(go.Scatter(mode='markers', marker=dict(size=12, color=colors[0],opacity=0.5),
                                x=XPS["B.E."].values,
                                 y=XPS["CPS"].values-XPS["Background CPS"].values))

fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[1],dash='dot'),
                                 x=XPS["B.E."].values,
                                 y=XPS["N-C/H.1"].values-XPS["Background CPS"].values))

fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[2],dash='dot'),
                                 x=XPS["B.E."].values,
                                 y=XPS["N-O.1"].values-XPS["Background CPS"].values))

fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[3],dash='dot'),
                                 x=XPS["B.E."].values,
                                 y=XPS["N+.1"].values-XPS["Background CPS"].values))


fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[7],dash='dash'),
                                 x=XPS["B.E."].values,
                                 y=XPS["Envelope CPS"].values-XPS["Background CPS"].values))

fig.update_layout(showlegend=False)

fig.show()

fig.write_image(Path+Folders[0]+"/"+"OCCA_N 1s"+".svg")
fig.write_image("C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/OCCA Perspective"+"/"+"N 1s"+".svg")

# %% [markdown]
# ## Depth profiling

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/OCCA/"
Folders=["New set"]
Files=["Al 2p.txt","As 3d.txt","Ga 3d.txt"]

colors=["blue", "red","green"]
markers=["circle","square","diamond"]

# read data
Al=pd.read_table(Path+Folders[0]+"/"+Files[0], skiprows=2)
As=pd.read_table(Path+Folders[0]+"/"+Files[1], skiprows=2)
Ga=pd.read_table(Path+Folders[0]+"/"+Files[2], skiprows=2)
time_step= 30 #s

#create a dataframe with the percentages
tot= Al["Area/(RSF*T*MFP)"].values+As["Area/(RSF*T*MFP)"].values+Ga["Area/(RSF*T*MFP)"].values
data = {'Al %':  Al["Area/(RSF*T*MFP)"].values/tot*100,
        'As %': As["Area/(RSF*T*MFP)"].values/tot*100,
        'Ga %': Ga["Area/(RSF*T*MFP)"].values/tot*100,
         }

XPS= pd.DataFrame(data)

# %%
fig = go.Figure()
fig.update_layout(template="plotly_white")
fig.update_layout(xaxis_title='Etching time (s)', yaxis_title='Atomic percentage (%)')
fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
fig.update_layout(font=dict(size=23))
#add the black box around the graph
fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
#add black ticks
fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
    
#fig.update_layout(legend=dict(orientation="h",yanchor="bottom",y=1.02,xanchor="left",x=0))
fig.update_layout(yaxis =dict(range=[-5,70]))
fig.update_layout(legend=dict(yanchor="top",y=1.0,xanchor="right",x=0.99, orientation="h"))
fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
fig.update_layout(autosize=False, width=550, height=500)
# do not use the k format for the thousands
fig.update_layout(xaxis = dict(exponentformat = 'none'))

s=len(XPS.index)-70 #5
e=len(XPS.index) #40


fig.add_trace(go.Scatter(mode='markers+lines', marker=dict(size=12,symbol=markers[0], color=colors[0],opacity=0.5),line=dict(dash="dashdot"),
                                 x=(XPS.index[s:e]-XPS.index[s])*time_step,
                                 y=XPS["Al %"].values[s:e],
                                name="Group V - element 1"))

fig.add_trace(go.Scatter(mode='markers+lines', marker=dict(size=12,symbol=markers[1], color=colors[1],opacity=0.5),line=dict(dash="dot"),
                                 x=(XPS.index[s:e]-XPS.index[s])*time_step,
                                 y=XPS["As %"].values[s:e],
                                 name= "Group III"))

fig.add_trace(go.Scatter(mode='markers+lines', marker=dict(size=12,symbol=markers[2], color=colors[2],opacity=0.5),line=dict(dash="dash"),
                                 x=(XPS.index[s:e]-XPS.index[s])*time_step,
                                 y=XPS["Ga %"].values[s:e],
                                name="Group V - element 2"))





fig.show()

fig.write_image("C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/OCCA Perspective"+"/"+"Depth profile_new"+".svg")

# %% [markdown]
# ### Bad quality

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/OCCA/"
Folders=["0019_290422_PH_MH_AJR_SPJ"]
Files=["Sb 3d","As 3d","Ga 3d"]

colors=["blue", "red","green"]
markers=["circle","square","diamond"]

# read data
Sb=pd.read_table(Path+Folders[0]+"/"+Files[0], skiprows=2)
As=pd.read_table(Path+Folders[0]+"/"+Files[1], skiprows=2)
Ga=pd.read_table(Path+Folders[0]+"/"+Files[2], skiprows=2)
time_step= 300 #s


Sb['%At Conc'] = Sb['%At Conc'].replace(['Unknown'],0)
data_types_dict = {'%At Conc': float}
Sb = Sb.astype(data_types_dict)

tot= Sb["%At Conc"].values+As["%At Conc"].values+Ga["%At Conc"].values
#create a dataframe with the percentages
data = {'Sb %':  Sb["%At Conc"].values/tot*100,
        'As %': As["%At Conc"].values/tot*100,
        'Ga %': Ga["%At Conc"].values/tot*100,
         }


XPS= pd.DataFrame(data)

# %%
fig = go.Figure()
fig.update_layout(template="plotly_white")
fig.update_layout(xaxis_title='Etching time (s)', yaxis_title='Atomic percentage (%)')
fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
fig.update_layout(font=dict(size=23))
#add the black box around the graph
fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
#add black ticks
fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
    
fig.update_layout(legend=dict(yanchor="top",y=0.49,xanchor="right",x=0.99))
fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
fig.update_layout(autosize=False, width=950, height=500)
# do not use the k format for the thousands
fig.update_layout(xaxis = dict(exponentformat = 'none'))

s=len(XPS.index)-70 #5
e=len(XPS.index) #40


fig.add_trace(go.Scatter(mode='markers+lines', marker=dict(size=12,symbol=markers[0], color=colors[0],opacity=0.5),line=dict(dash="dashdot"),
                                 x=(XPS.index[s:e]-XPS.index[s])*time_step,
                                 y=XPS["Sb %"].values[s:e],
                                name="Group V - element 1"))

fig.add_trace(go.Scatter(mode='markers+lines', marker=dict(size=12,symbol=markers[1], color=colors[1],opacity=0.5),line=dict(dash="dot"),
                                 x=(XPS.index[s:e]-XPS.index[s])*time_step,
                                 y=XPS["As %"].values[s:e],
                                 name= "Group V - element 2"))

fig.add_trace(go.Scatter(mode='markers+lines', marker=dict(size=12,symbol=markers[2], color=colors[2],opacity=0.5),line=dict(dash="dash"),
                                 x=(XPS.index[s:e]-XPS.index[s])*time_step,
                                 y=XPS["Ga %"].values[s:e],
                                name="Group III"))



fig.update_layout(showlegend=True)

fig.show()

fig.write_image("C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/OCCA Perspective"+"/"+"Depth profile_new"+".svg")

# %% [markdown]
# ### Bad quality data

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/"
Folders=["OCCA"]
Files=["Al.txt","As.txt","Ga.txt"]

colors=["blue", "red","green"]
markers=["circle","square","diamond"]

# read data
Al=pd.read_table(Path+Folders[0]+"/"+Files[0], skiprows=0)
As=pd.read_table(Path+Folders[0]+"/"+Files[1], skiprows=2)
Ga=pd.read_table(Path+Folders[0]+"/"+Files[2], skiprows=2)
time_step= 30 #s

#create a dataframe with the percentages
tot= Al["Area/(RSF*T*MFP)"].values+As["Area/(RSF*T*MFP)"].values+Ga["Area/(RSF*T*MFP)"].values
data = {'Al %':  Al["Area/(RSF*T*MFP)"].values/tot,
        'As %': As["Area/(RSF*T*MFP)"].values/tot,
        'Ga %': Ga["Area/(RSF*T*MFP)"].values/tot,
         }

XPS= pd.DataFrame(data)

# %%
fig = go.Figure()
fig.update_layout(template="plotly_white")
fig.update_layout(xaxis_title='Etching time (s)', yaxis_title='Atomic percentage (%)')
fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
fig.update_layout(font=dict(size=23))
#add the black box around the graph
fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
#add black ticks
fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
    
fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
fig.update_layout(autosize=False, width=550, height=500)
    


fig.add_trace(go.Scatter(mode='markers+lines', marker=dict(size=12,symbol=markers[0], color=colors[0],opacity=0.5),
                                 x=XPS.index*time_step,
                                 y=XPS["Al %"].values*100,
                                name="Al"))

fig.add_trace(go.Scatter(mode='markers+lines', marker=dict(size=12,symbol=markers[1], color=colors[1],opacity=0.5),
                                 x=XPS.index*time_step,
                                 y=XPS["As %"].values*100,
                                 name= "As"))

fig.add_trace(go.Scatter(mode='markers+lines', marker=dict(size=12,symbol=markers[2], color=colors[2],opacity=0.5),
                                 x=XPS.index*time_step,
                                 y=XPS["Ga %"].values*100,
                                name="Ga"))



fig.update_layout(showlegend=True)

fig.show()

fig.write_image("C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/OCCA Perspective"+"/"+"Depth profile"+".svg")

# %% [markdown]
# # Cu 5

# %% [markdown]
# ## HOPG

# %% [markdown]
# ### Cu 2p

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/Br4TPP/Cu5 High resolution/"
Folders=['0013_150922_AQ']  #["0004_040621_AQ"]
Files=["Cu5_HOPG_Cu 2p"]  

names=["25 °C", "50 °C UHV","50 °C Air"]
titles=["Cu5 HOPG Cu 2p"]

symbol=["circle","cross","diamond"]
colors=["blue", "red", "green"]

length=168 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range(0,len(Files)):
    
    FolderTR=Path+Folders[j]
    DataPerSpectrum=DataPerSpectra[j] #number of rows of each spectrum including the headers
    FileXPS=Files[j]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra=int(XPS.shape[0]//NumericDataPerSpectrum)

    XPS=xl.RemoveLinearBackgorund(XPS, Points=50, NumberOfSpectra=NumberOfSpectra)

    
    x_len=XPS.shape[0]//NumberOfSpectra
    
    print(x_len)
    print(NumberOfSpectra)
    
    print(len(XPS["Binding Energy"].values))
    
    
    fig = go.Figure()
    fig.update_layout(template="plotly_white")
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='CPS')
    fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
    fig.update_layout(font=dict(size=23))
    #add the black box around the graph
    fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    #add black ticks
    fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
    fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
    
    fig.update_layout(xaxis = dict(autorange = "reversed"))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
    fig.update_layout(autosize=False, width=550, height=500)
    
    for i in range (0, NumberOfSpectra):
        fig.add_trace(go.Scatter(mode='markers',marker_symbol=symbol[i], marker=dict(size=6, color=colors[i]),
                                 x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
                                 y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i],
                                 name=names[i]))
    
fig.write_image(FolderTR+"/"+titles[j]+".png")
fig.write_image(FolderTR+"/"+titles[j]+".svg")
fig.show()

# %% [markdown]
# ### Cu 3p of Br4TPP+ Cu$_5$ at different T

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/Br4TPP/HOPG/"
Folders=["0007_100521_LF"]
Files=["Cu.csv"]

names=["25 °C", "250 °C"]
titles=["Cu5 HOPG Cu 2p"]

symbol=["circle","cross","diamond"]
colors=["blue", "red", "green"]

length=168 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range(0,len(Files)):
    
    FolderTR=Path+Folders[j]
    DataPerSpectrum=DataPerSpectra[j] #number of rows of each spectrum including the headers
    FileXPS=Files[j]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra=int(XPS.shape[0]//NumericDataPerSpectrum)

    #XPS=xl.RemoveLinearBackgorund(XPS, Points=50, NumberOfSpectra=NumberOfSpectra)

    
    x_len=XPS.shape[0]//NumberOfSpectra
    
    print(x_len)
    print(NumberOfSpectra)
    
    print(len(XPS["Binding Energy"].values))
    
    
    fig = go.Figure()
    fig.update_layout(template="plotly_white")
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='CPS')
    fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
    fig.update_layout(font=dict(size=23))
    #add the black box around the graph
    fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    #add black ticks
    fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
    fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
    
    fig.update_layout(xaxis = dict(autorange = "reversed"))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
    fig.update_layout(autosize=False, width=550, height=500)
    
    for i in range (0, NumberOfSpectra):
        fig.add_trace(go.Scatter(mode='lines',marker_symbol=symbol[i], marker=dict(size=6, color=colors[i]),
                                 x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
                                 y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i],
                                 name=names[i]))
    
fig.write_image(FolderTR+"/"+titles[j]+".png")
fig.write_image(FolderTR+"/"+titles[j]+".svg")
fig.show()

# %% [markdown]
# ### Auger

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/Br4TPP/Cu5 High resolution/"
Folders=['0013_150922_AQ']  #["0004_040621_AQ"]
Files=["Cu5_HOPG_Auger"]  

names=["25 °C", "50 °C UHV","50 °C Air"]
titles=["Cu5 HOPG Auger"]

symbol=["circle","cross","diamond"]
colors=["blue", "red", "green"]

length=168 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range(0,len(Files)):
    
    FolderTR=Path+Folders[j]
    DataPerSpectrum=DataPerSpectra[j] #number of rows of each spectrum including the headers
    FileXPS=Files[j]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra=int(XPS.shape[0]//NumericDataPerSpectrum)
    
    Mask=np.logical_and( XPS["Binding Energy"] >565, XPS["Binding Energy"] < 585)
    XPS=XPS[Mask]
    #Mask=XPS["CPS"]>-5
    #XPS=XPS[Mask]
    x_len=XPS.shape[0]//NumberOfSpectra

    XPS=xl.RemoveLinearBackgorund(XPS, Points=50, NumberOfSpectra=NumberOfSpectra)

    
    x_len=XPS.shape[0]//NumberOfSpectra
    
    print(x_len)
    print(NumberOfSpectra)
    
    print(len(XPS["Binding Energy"].values))
    
    
    fig = go.Figure()
    fig.update_layout(template="plotly_white")
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='CPS')
    fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
    fig.update_layout(font=dict(size=23))
    #add the black box around the graph
    fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    #add black ticks
    fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
    fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
    
    fig.update_layout(xaxis = dict(autorange = "reversed"))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
    fig.update_layout(autosize=False, width=550, height=500)
    
    for i in range (0, NumberOfSpectra):
        fig.add_trace(go.Scatter(mode='markers',marker_symbol=symbol[i], marker=dict(size=6, color=colors[i]),
                                 x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
                                 y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i]-np.min(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i]),
                                 name=names[i]))
    
fig.write_image(FolderTR+"/"+titles[j]+".png")
fig.write_image(FolderTR+"/"+titles[j]+".svg")
fig.show()

# %% [markdown]
# ### Auger Better quality

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/Br4TPP/Cu5 High resolution/"
Folders=['0019_290922_AQ']  #["0004_040621_AQ"]
Files=["HOPG_Auger"]  

names=["25 °C", "50 °C UHV","50 °C Air"]
titles=["Cu5 HOPG Auger"]

symbol=["circle","cross","diamond"]
colors=["blue", "red", "green"]

length=168 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range(0, len(Files)):

    FolderTR = Path + Folders[j]
    DataPerSpectrum = DataPerSpectra[
        j]  #number of rows of each spectrum including the headers
    FileXPS = Files[j]
    NumericDataPerSpectrum = xl.Count_DataPerSpectrum(
        FolderTR + "/" +
        FileXPS) - HeaderColumns  #number of rows with the numeric data
    #Read the XPS data and assign them to a pandas dataframe
    XPS = xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra = int(XPS.shape[0] // NumericDataPerSpectrum)

    Mask = np.logical_and(XPS["Binding Energy"] > 565,
                          XPS["Binding Energy"] < 585)
    XPS = XPS[Mask]
    #Mask=XPS["CPS"]>-5
    #XPS=XPS[Mask]
    x_len = XPS.shape[0] // NumberOfSpectra

    XPS = xl.RemoveLinearBackgorund(XPS,
                                    Points=50,
                                    NumberOfSpectra=NumberOfSpectra)

    x_len = XPS.shape[0] // NumberOfSpectra

    print(x_len)
    print(NumberOfSpectra)

    print(len(XPS["Binding Energy"].values))

    fig = go.Figure()
    fig.update_layout(template="plotly_white")
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='CPS')
    fig.update_layout(yaxis=dict(tickfont=dict(size=23)),
                      xaxis=dict(tickfont=dict(size=23)))
    fig.update_layout(font=dict(size=23))
    #add the black box around the graph
    fig.update_xaxes(showline=True,
                     linewidth=4,
                     linecolor='black',
                     mirror=True)
    fig.update_yaxes(showline=True,
                     linewidth=4,
                     linecolor='black',
                     mirror=True)
    #add black ticks
    fig.update_xaxes(showgrid=True, ticks="outside", tickwidth=4)
    fig.update_yaxes(showgrid=True, ticks="outside", tickwidth=4)

    fig.update_layout(xaxis=dict(autorange="reversed"))
    fig.update_layout(
        legend=dict(yanchor="top", y=0.99, xanchor="right", x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0, r=0, b=20, t=0))  #t=50
    fig.update_layout(autosize=False, width=550, height=500)

    for i in range(0, NumberOfSpectra):
        fig.add_trace(
            go.Scatter(
                mode='markers',
                marker_symbol=symbol[i],
                marker=dict(size=6, color=colors[i]),
                x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,
                                                       x_len)[i],
                y=XPS["CPS"].values.reshape(NumberOfSpectra, x_len)[i] -
                np.min(XPS["CPS"].values.reshape(NumberOfSpectra, x_len)[i]),
                name=names[i]))

fig.write_image(FolderTR + "/" + titles[j] + ".png")
fig.write_image(FolderTR + "/" + titles[j] + ".svg")
fig.show()

# %% [markdown]
# ### Auger Right Range

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/Br4TPP/Cu5 High resolution/"
Folders=['0002_041022_AQ']  #["0004_040621_AQ"]
Files=["HOPG_Auger_Raw"]  

names=["25 °C", "50 °C UHV","50 °C Air"]
titles=["Cu5 HOPG Auger"]

symbol=["circle","cross","diamond"]
colors=["blue", "red", "green"]

length=309 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range(0, len(Files)):

    FolderTR = Path + Folders[j]
    DataPerSpectrum = DataPerSpectra[j]  #number of rows of each spectrum including the headers
    FileXPS = Files[j]
    NumericDataPerSpectrum = xl.Count_DataPerSpectrum(FolderTR + "/" +FileXPS) - HeaderColumns  #number of rows with the numeric data
    #Read the XPS data and assign them to a pandas dataframe
    XPS = xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra = int(XPS.shape[0] // NumericDataPerSpectrum)
   
    x_len = XPS.shape[0] // NumberOfSpectra
    
    Mask=np.logical_and( XPS["Binding Energy"] >566, XPS["Binding Energy"] < 585)
    XPS=XPS[Mask]

    XPS = xl.RemoveLinearBackgorund(XPS,Points=10,NumberOfSpectra=NumberOfSpectra)

    x_len = XPS.shape[0] // NumberOfSpectra

    print(x_len)
    print(NumberOfSpectra)
    
    #Average the data
    CPS_average=np.mean(XPS["CPS"].values.reshape(NumberOfSpectra,x_len),axis=0)
    
    fig.update_layout(template="plotly_white")
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='CPS (a.u.)')
    fig.update_yaxes(showticklabels=False,title_standoff = 30)

    fig.update_layout(yaxis = dict( tickfont = dict(size = 30)), xaxis = dict( tickfont = dict(size = 30)))
    fig.update_layout(font=dict(size=30))
    #add the black box around the graph
    fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    #add black ticks
    fig.update_xaxes(showgrid=True,ticks="inside",tickwidth=4)
    fig.update_yaxes(showgrid=True,ticks="inside",tickwidth=4)
    
    #fig.update_layout(xaxis = dict(range = [960.1,924.9]))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
    fig.update_layout(autosize=False, width=550, height=500)

    for i in range(0, 1):
        fig.add_trace(
            go.Scatter(
                mode='lines',
                marker_symbol=symbol[i],
                line=dict(width=4, color=colors[i]),
                x=XPS["Binding Energy"].values.reshape(NumberOfSpectra, x_len)[i],
                y=CPS_average-np.min(CPS_average),
                name=names[i]))
        
    fig.update_layout(showlegend=False)

#fig.write_image(FolderTR + "/" + titles[j] + "KE .png")
#fig.write_image(FolderTR + "/" + titles[j] + "KE .svg")
fig.show()

# %% [markdown]
# ### Auger Right Range -2

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/Br4TPP/Cu5 High resolution/"
Folders=['0004_061022_AQ']  #["0004_040621_AQ"]
Files=["HOPG_Auger_Raw"]  

names=["25 °C", "50 °C UHV","50 °C Air"]
titles=["Cu5 HOPG Auger"]

symbol=["circle","cross","diamond"]
colors=["blue", "red", "green"]

length=309 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range(0, len(Files)):

    FolderTR = Path + Folders[j]
    DataPerSpectrum = DataPerSpectra[j]  #number of rows of each spectrum including the headers
    FileXPS = Files[j]
    NumericDataPerSpectrum = xl.Count_DataPerSpectrum(FolderTR + "/" +FileXPS) - HeaderColumns  #number of rows with the numeric data
    #Read the XPS data and assign them to a pandas dataframe
    XPS = xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra = int(XPS.shape[0] // NumericDataPerSpectrum)
   
    x_len = XPS.shape[0] // NumberOfSpectra
    
    Mask=np.logical_and( XPS["Binding Energy"] >566, XPS["Binding Energy"] < 585)
    XPS=XPS[Mask]

    XPS = xl.RemoveLinearBackgorund(XPS,Points=10,NumberOfSpectra=NumberOfSpectra)

    x_len = XPS.shape[0] // NumberOfSpectra

    print(x_len)
    print(NumberOfSpectra)
    
    #Average the data
    CPS_average=np.mean(XPS["CPS"].values.reshape(NumberOfSpectra,x_len),axis=0)
    
    fig = go.Figure()
    for i in range(0, 1):
        fig.add_trace(
            go.Scatter(
                mode='lines',
                marker_symbol=symbol[i],
                line=dict(width=4, color=colors[i]),
                x=1486.6-XPS["Binding Energy"].values.reshape(NumberOfSpectra, x_len)[i],
                y=CPS_average-np.min(CPS_average),
                name=names[i]))
        
Aesthetics(fig)
fig.update_xaxes(title='Kinetic Energy (eV)')


fig.write_image(FolderTR + "/" + titles[j] + "KE .png")
fig.write_image(FolderTR + "/" + titles[j] + "KE .svg")
#fig.write_image("C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Publications/Synchrotron Paper/Figures/RawFigures"+"/" +titles[j] + "KE .svg")
fig.show()

# %% [markdown]
# ## Au(111)

# %% [markdown]
# ### Cu 2p

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/Br4TPP/Cu5 High resolution/"
Folders=['0015_200922_AQ']  
Files=["Au_Cu 2p_High resolution"]  

names=["25 °C", "50 °C UHV","50 °C Air"]
titles=["Cu5 Au(111) Cu 2p"]

symbol=["circle","cross","diamond"]
colors=["blue", "red", "green"]

length=168 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

for j in range(0,len(Files)):
    
    FolderTR=Path+Folders[j]
    DataPerSpectrum=DataPerSpectra[j] #number of rows of each spectrum including the headers
    FileXPS=Files[j]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra=int(XPS.shape[0]//NumericDataPerSpectrum)

    XPS=xl.RemoveLinearBackgorund(XPS, Points=50, NumberOfSpectra=NumberOfSpectra)

    
    x_len=XPS.shape[0]//NumberOfSpectra
    
    print(x_len)
    print(NumberOfSpectra)
    
    print(len(XPS["Binding Energy"].values))
    
    
    fig = go.Figure()
    fig.update_layout(template="plotly_white")
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='Intensity (a.u.)')
    fig.update_yaxes(showticklabels=False, title_standoff = 30)

    fig.update_layout(yaxis = dict( tickfont = dict(size = 30)), xaxis = dict( tickfont = dict(size = 30)))
    fig.update_layout(font=dict(size=30))
    #add the black box around the graph
    fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    #add black ticks
    fig.update_xaxes(showgrid=True,ticks="inside",tickwidth=4)
    fig.update_yaxes(showgrid=True,ticks="inside",tickwidth=4)
    
    fig.update_layout(xaxis = dict(range = [960.1,924.9]))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
    fig.update_layout(autosize=False, width=550, height=500)
    
    for i in range (0, NumberOfSpectra):
        fig.add_trace(go.Scatter(mode='lines',marker_symbol=symbol[i], line=dict(width=4, color=colors[i]),
                                 x=3.8+XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
                                 y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i],
                                 name=names[i]))
    
fig.write_image(FolderTR+"/"+titles[j]+".png")
fig.write_image(FolderTR+"/"+titles[j]+".svg")
fig.write_image("C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Publications/Synchrotron Paper/Figures/RawFigures"+"/"+titles[j]+".svg")
fig.show()

# %% [markdown]
# ### Auger

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/Br4TPP/Cu5 High resolution/"
Folders=['0009_151222_AQ'] 
Files=["Cu Auger"]  

names=[" ",]
titles=["Cu5 Au(111) Auger"]

symbol=["circle","cross","diamond"]
colors=["blue", "red", "green"]

length=309 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range(0, len(Files)):

    FolderTR = Path + Folders[j]
    DataPerSpectrum = DataPerSpectra[j]  #number of rows of each spectrum including the headers
    FileXPS = Files[j]
    NumericDataPerSpectrum = xl.Count_DataPerSpectrum(FolderTR + "/" +FileXPS) - HeaderColumns  #number of rows with the numeric data
    #Read the XPS data and assign them to a pandas dataframe
    XPS = xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra = int(XPS.shape[0] // NumericDataPerSpectrum)
   
    x_len = XPS.shape[0] // NumberOfSpectra
    
    #Mask=np.logical_and( XPS["Binding Energy"] >566, XPS["Binding Energy"] < 585)
    #XPS=XPS[Mask]

    #XPS = xl.RemoveLinearBackgorund(XPS,Points=10,NumberOfSpectra=NumberOfSpectra)

    x_len = XPS.shape[0] // NumberOfSpectra

    print(x_len)
    print(NumberOfSpectra)
    
    #Average the data
    
    fig = go.Figure()
    fig.update_layout(template="plotly_white")
    fig.update_layout(xaxis_title='Kinetic Energy (eV)', yaxis_title='Intensity (a.u.)')
    fig.update_yaxes(showticklabels=False, title_standoff = 30 )

    fig.update_layout(yaxis = dict( tickfont = dict(size = 30)), xaxis = dict( tickfont = dict(size = 30)))
    fig.update_layout(font=dict(size=30))
    #add the black box around the graph
    fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    #add black ticks
    fig.update_xaxes(showgrid=True,ticks="inside",tickwidth=4)
    fig.update_yaxes(showgrid=True,ticks="inside",tickwidth=4)
    
    #fig.update_layout(yaxis = dict(range = [1500,4500]))
    fig.update_layout(xaxis = dict(range = [908,930]))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
    fig.update_layout(autosize=False, width=800, height=600)

    for i in range(0, NumberOfSpectra):
        fig.add_trace(
            go.Scatter(
                mode='lines',marker_symbol=symbol[i], line=dict(width=4, color=colors[i]),
                x=1486.6-XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
                y=XPS["CPS"].values.reshape(NumberOfSpectra, x_len)[i] -np.min(XPS["CPS"].values.reshape(NumberOfSpectra, x_len)[i]),
                name=names[i]))

fig.write_image(FolderTR + "/" + titles[j] + "KE .png")
fig.write_image(FolderTR + "/" + titles[j] + "KE .svg")
#fig.write_image("C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Publications/Synchrotron Paper/Figures/RawFigures"+"/"+titles[j]+".svg")

fig.show()

# %% [markdown]
# ### Auger Improved quality

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/Br4TPP/Cu5 High resolution/"
Folders=['0003_100123_AQ_CW'] 
Files=["Cu Auger"]  

names=[" ",]
titles=["Cu5 Au(111) Auger"]

symbol=["circle","cross","diamond"]
colors=["blue", "red", "green"]

length=309 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range(0, len(Files)):

    FolderTR = Path + Folders[j]
    DataPerSpectrum = DataPerSpectra[j]  #number of rows of each spectrum including the headers
    FileXPS = Files[j]
    NumericDataPerSpectrum = xl.Count_DataPerSpectrum(FolderTR + "/" +FileXPS) - HeaderColumns  #number of rows with the numeric data
    #Read the XPS data and assign them to a pandas dataframe
    XPS = xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra = int(XPS.shape[0] // NumericDataPerSpectrum)
   
    x_len = XPS.shape[0] // NumberOfSpectra
    
    #Mask=np.logical_and( XPS["Binding Energy"] >566, XPS["Binding Energy"] < 585)
    #XPS=XPS[Mask]

    #XPS = xl.RemoveLinearBackgorund(XPS,Points=10,NumberOfSpectra=NumberOfSpectra)

    x_len = XPS.shape[0] // NumberOfSpectra

    print(x_len)
    print(NumberOfSpectra)
    
    #Average the data
    
    fig = go.Figure()
    fig.update_layout(template="plotly_white")
    fig.update_layout(xaxis_title='Kinetic Energy (eV)', yaxis_title='Intensity (a.u.)')
    fig.update_yaxes(showticklabels=False, title_standoff = 30 )

    fig.update_layout(yaxis = dict( tickfont = dict(size = 30)), xaxis = dict( tickfont = dict(size = 30)))
    fig.update_layout(font=dict(size=30))
    #add the black box around the graph
    fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    #add black ticks
    fig.update_xaxes(showgrid=True,ticks="inside",tickwidth=4)
    fig.update_yaxes(showgrid=True,ticks="inside",tickwidth=4)
    
    #fig.update_layout(yaxis = dict(range = [1500,4500]))
    fig.update_layout(xaxis = dict(range = [912,924]))
    fig.update_layout(yaxis = dict(range = [1900,5000]))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
    fig.update_layout(autosize=False, width=550, height=500)

    y_average=np.mean(XPS["CPS"].values.reshape(NumberOfSpectra, x_len), axis=0)
        
    fig.add_trace(
        go.Scatter(
            mode='lines',marker_symbol=symbol[i], line=dict(width=4, color=colors[i]),
            x=1486.6-XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
            y=y_average-np.min(y_average),
            name=names[i]))
fig.show()

fig.write_image(FolderTR + "/" + titles[j] + "KE .png")
fig.write_image(FolderTR + "/" + titles[j] + "KE .svg")
fig.write_image("C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Publications/Synchrotron Paper/Figures/RawFigures"+"/"+titles[j]+".svg")

# %% [markdown]
# ## Auger Au(111 control)

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/Br4TPP/Cu5 High resolution/"
Folders=['0009_151222_AQ'] 
Files=["Au(111) Auger Control"]  

names=[" ",]
titles=["Au(111) Auger Control"]

symbol=["circle","cross","diamond"]
colors=["blue", "red", "green"]

length=309 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range(0, len(Files)):

    FolderTR = Path + Folders[j]
    DataPerSpectrum = DataPerSpectra[j]  #number of rows of each spectrum including the headers
    FileXPS = Files[j]
    NumericDataPerSpectrum = xl.Count_DataPerSpectrum(FolderTR + "/" +FileXPS) - HeaderColumns  #number of rows with the numeric data
    #Read the XPS data and assign them to a pandas dataframe
    XPS = xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra = int(XPS.shape[0] // NumericDataPerSpectrum)
   
    x_len = XPS.shape[0] // NumberOfSpectra
    
    #Mask=np.logical_and( XPS["Binding Energy"] >566, XPS["Binding Energy"] < 585)
    #XPS=XPS[Mask]

    #XPS = xl.RemoveLinearBackgorund(XPS,Points=10,NumberOfSpectra=NumberOfSpectra)

    x_len = XPS.shape[0] // NumberOfSpectra

    print(x_len)
    print(NumberOfSpectra)
    
    #Average the data
    
    fig = go.Figure()
    fig.update_layout(template="plotly_white")
    fig.update_layout(xaxis_title='Kinetic Energy (eV)', yaxis_title='Intensity (a.u.)')
    fig.update_yaxes(showticklabels=False, title_standoff = 30 )

    fig.update_layout(yaxis = dict( tickfont = dict(size = 30)), xaxis = dict( tickfont = dict(size = 30)))
    fig.update_layout(font=dict(size=30))
    #add the black box around the graph
    fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    #add black ticks
    fig.update_xaxes(showgrid=True,ticks="inside",tickwidth=4)
    fig.update_yaxes(showgrid=True,ticks="inside",tickwidth=4)
    
    #fig.update_layout(yaxis = dict(range = [1500,4500]))
    fig.update_layout(xaxis = dict(range = [912,924]))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
    fig.update_layout(autosize=False, width=550, height=500)

    for i in range(0, NumberOfSpectra):
        fig.add_trace(
            go.Scatter(
                mode='lines',marker_symbol=symbol[i], line=dict(width=4, color=colors[i]),
                x=1486.6-XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
                y=XPS["CPS"].values.reshape(NumberOfSpectra, x_len)[i] -np.min(XPS["CPS"].values.reshape(NumberOfSpectra, x_len)[i]),
                name=names[i]))

fig.write_image(FolderTR + "/" + titles[j] + "KE .png")
fig.write_image(FolderTR + "/" + titles[j] + "KE .svg")
fig.write_image("C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Publications/Synchrotron Paper/Figures/SI/Raw"+"/"+titles[j]+".svg")

fig.show()

# %% [markdown]
# ## Mica

# %% [markdown]
# ### Cu 2p

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/Br4TPP/Cu5 High resolution/"
Folders=['0018_220922_AQ']  
Files=["Mica_Cu 2p_High res"]  

names=["25 °C", "50 °C UHV","50 °C Air"]
titles=["Cu5 HOPG Cu 2p"]

symbol=["circle","cross","diamond"]
colors=["blue", "red", "green"]

length=168 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

for j in range(0,len(Files)):
    
    FolderTR=Path+Folders[j]
    DataPerSpectrum=DataPerSpectra[j] #number of rows of each spectrum including the headers
    FileXPS=Files[j]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra=int(XPS.shape[0]//NumericDataPerSpectrum)

    XPS=xl.RemoveLinearBackgorund(XPS, Points=50, NumberOfSpectra=NumberOfSpectra)

    
    x_len=XPS.shape[0]//NumberOfSpectra
    
    print(x_len)
    print(NumberOfSpectra)
    
    print(len(XPS["Binding Energy"].values))
    
    
    fig = go.Figure()
    fig.update_layout(template="plotly_white")
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='CPS')
    fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
    fig.update_layout(font=dict(size=23))
    #add the black box around the graph
    fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    #add black ticks
    fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
    fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
    
    fig.update_layout(xaxis = dict(autorange = "reversed"))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
    fig.update_layout(autosize=False, width=550, height=500)
    
    for i in range (0, NumberOfSpectra):
        fig.add_trace(go.Scatter(mode='markers',marker_symbol=symbol[i], marker=dict(size=6, color=colors[i]),
                                 x=3.7+XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
                                 y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i],
                                 name=names[i]))
    
#fig.write_image(FolderTR+"/"+titles[j]+".png")
#fig.write_image(FolderTR+"/"+titles[j]+".svg")
fig.show()

# %% [markdown]
# # Metalation of porphyrin ?

# %% [markdown]
# ## HOPG

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/Br4TPP/HOPG/Reply to referees/"
Folders=['0006_081122_AQ']  
Files=["N1s_26C_400C"]#["N1s_26C_400C"]  

names=["26 °C", "400 °C"]
titles=["N1s_26C","N1s_400C"]

symbol=["circle","cross","diamond"]
colors=["blue", "red", "green"]

length=168 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

for j in range(0,len(Files)):
    
    FolderTR=Path+Folders[j]
    DataPerSpectrum=DataPerSpectra[j] #number of rows of each spectrum including the headers
    FileXPS=Files[j]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra=int(XPS.shape[0]//NumericDataPerSpectrum)

    #XPS=xl.RemoveLinearBackgorund(XPS, Points=10, NumberOfSpectra=NumberOfSpectra)

    
    x_len=XPS.shape[0]//NumberOfSpectra
    
    print(x_len)
    print(NumberOfSpectra)
    
    print(len(XPS["Binding Energy"].values))
    
    
    fig = go.Figure()
    fig.update_layout(template="plotly_white")
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='CPS')
    fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
    fig.update_layout(font=dict(size=23))
    #add the black box around the graph
    fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    #add black ticks
    fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
    fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
    
    fig.update_layout(xaxis = dict(autorange = "reversed"))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
    fig.update_layout(autosize=False, width=550, height=500)
    
    for i in range (0, NumberOfSpectra):
        fig.add_trace(go.Scatter(mode='lines',marker_symbol=symbol[i], marker=dict(size=6, color=colors[i]),
                                 x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
                                 y=(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i]-np.min(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i]))/(np.max(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i])-np.min(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i])),
                                 name=names[i]))
    
fig.write_image(FolderTR+"/"+titles[j]+".png")
fig.write_image(FolderTR+"/"+titles[j]+".svg")
fig.show()

# %% [markdown]
# # Br 3p at different T for synchrotron papaer

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/Br4TPP/Au/"
Folders=['LeoTPXPS','LeoTPXPS']  
Files=["Br_BackgroundSubtracted"]#["N1s_26C_400C"]  

names=["290 K", "350 K"]
titles=["Br3p","Br3p"]

symbol=["circle","cross","diamond"]
#colors=["blue", "red", "green"]

length=168 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

Columns=["K.E.", "Counts", "Background", "Envelope","Binding Energy", "CPS", "Background CPS", "Envelope CPS"]

for j in range(0,len(Files)):
    
    FolderTR=Path+Folders[j]
    DataPerSpectrum=DataPerSpectra[j] #number of rows of each spectrum including the headers
    FileXPS=Files[j]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSDataFitted(FolderTR, FileXPS,HeaderColumns, Columns)
    #number of spectra composing the dataset
    NumberOfSpectra=int(XPS.shape[0]//NumericDataPerSpectrum)

    XPS=xl.RemoveLinearBackgorund(XPS, Points=1, NumberOfSpectra=NumberOfSpectra)

    
    x_len=XPS.shape[0]//NumberOfSpectra
    
    print(x_len)
    print(NumberOfSpectra)    
    
    fig = go.Figure()
    
    
    fig.update_layout(xaxis = dict(range = [192.2,178.8]))
    Aesthetics(fig)


    
    for i in range (0, NumberOfSpectra):
        fig.add_trace(go.Scatter(mode='lines', line=dict(width=4),
                                 x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
                                 y=(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i]-np.min(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i])),
                                name=names[i]))
    
fig.write_image(FolderTR+"/"+titles[j]+".png")
fig.write_image(FolderTR+"/"+titles[j]+".svg")
fig.write_image("C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Publications/Synchrotron Paper/Figures/RawFigures"+"/"+"Br XPS"+".svg")

fig.show()

# %% [markdown]
# # Yue

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/Yue/"
Folders=["0011_111122_AQ_YC_SPJ","0011_111122_AQ_YC_SPJ","0011_111122_AQ_YC_SPJ","0011_111122_AQ_YC_SPJ"]
Files=["Na 1s","F 1s", "O 1s", "C1s"]

names=["25 °C", "50 °C UHV","50 °C Air"]
titles=["Na 1s","F 1s", "O 1s", "C1s"]

symbol=["circle","cross","diamond"]
colors=["blue", "red", "green"]

length=168 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range(0,len(Files)):
    
    FolderTR=Path+Folders[j]
    DataPerSpectrum=DataPerSpectra[j] #number of rows of each spectrum including the headers
    FileXPS=Files[j]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra=int(XPS.shape[0]//NumericDataPerSpectrum)

    #XPS=xl.RemoveLinearBackgorund(XPS, Points=50, NumberOfSpectra=NumberOfSpectra)

    x_len=XPS.shape[0]//NumberOfSpectra
    
    print(x_len)
    print(NumberOfSpectra)
    
    
    
    fig = go.Figure()
    
    for i in range (0, NumberOfSpectra):
        fig.add_trace(go.Scatter(mode='lines',line=dict(width=3, color="royal blue"),
                                 x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
                                 y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i],
                                 name=names[i]))
    
    Aesthetics(fig)
    fig.update_layout(xaxis = dict(autorange = "reversed"))
    
    fig.write_image(FolderTR+"/"+titles[j]+".png")
    fig.write_image(FolderTR+"/"+titles[j]+".svg")
    fig.show()

# %% [markdown]
# # Thesis

# %% [markdown]
# ## Examples

# %% [markdown]
# ### C1s

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/"
Folders=["TEMPO"]
Files=["C1s_TEMPO Fit"]

length=239 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

colors=["gray", "blue", "red", "black","green","violet","brown","orange"]

#columns of the file to read
XPS=pd.read_table(Path+Folders[0]+"/"+Files[0], skiprows=lambda x: x%DataPerSpectra<HeaderColumns-1, header=0)

# %%
fig = go.Figure()
fig.update_layout(template="plotly_white")
fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='Intensity (CPS)')
fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
fig.update_layout(font=dict(size=23))
#add the black box around the graph
fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
#add black ticks
fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
    
fig.update_layout(xaxis =dict(range=[292,280]))
fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
fig.update_layout(autosize=False, width=550, height=500)
# do not use the k format for the thousands
fig.update_layout(yaxis = dict(exponentformat = 'none'))
# tick every 2eV
fig.update_layout( xaxis = dict(tickmode = 'linear',tick0 = 0,dtick = 2))


fig.add_trace(go.Scatter(mode='markers', marker=dict(size=12, color=colors[0],opacity=0.5),
                                 x=XPS["B.E."].values,
                                 y=XPS["CPS"].values-XPS["Background CPS"].values))

#fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[1],dash='dot'),
                                 #x=XPS["B.E."].values,
                                 #y=XPS["C-F2.1"].values-XPS["Background CPS"].values))

fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[2],dash='dot'),
                                 x=XPS["B.E."].values,
                                 y=XPS["C-C/H"].values-XPS["Background CPS"].values))

fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[3],dash='dot'),
                                 x=XPS["B.E."].values,
                                 y=XPS["C-N"].values-XPS["Background CPS"].values))


fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[4],dash='dot'),
                                 x=XPS["B.E."].values,
                                 y=XPS["C-O"].values-XPS["Background CPS"].values))

fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[5],dash='dot'),
                                 x=XPS["B.E."].values,
                                 y=XPS["C=O"].values-XPS["Background CPS"].values))

fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[6],dash='dot'),
                                 x=XPS["B.E."].values,
                                 y=XPS["O-C=O"].values-XPS["Background CPS"].values))


fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[7],dash='dash'),
                                 x=XPS["B.E."].values,
                                 y=XPS["Envelope CPS"].values-XPS["Background CPS"].values))

fig.update_layout(showlegend=False)

fig.show()

fig.write_image("C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Thesis/Chapters/Methods and Materials"+"/"+"XPS_Carbon1s"+".png")
fig.write_image("C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Thesis/Chapters/Methods and Materials"+"/"+"XPS_Carbon1s"+".svg")
fig.write_html("C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Thesis/Chapters/Methods and Materials"+"/"+"Carbon1s"+".html")

# %% [markdown]
# ### N 1s

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/TEMPO/"

Folders=["0021_300321_AQ"]
Files=["N1s_Fitted_Upstream_OCCA.txt"]


length=169 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

colors=["gray", "blue", "red", "black","green","violet","brown","orange"]

#columns of the file to read
XPS=pd.read_table(Path+Folders[0]+"/"+Files[0], skiprows=lambda x: x%DataPerSpectra<HeaderColumns-1, header=0)

# %%
fig = go.Figure()
fig.update_layout(template="plotly_white")
fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='Intensity (CPS)')
fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
fig.update_layout(font=dict(size=23))
#add the black box around the graph
fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
#add black ticks
fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
    
fig.update_layout(xaxis =dict(range=[406,394]))
fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
fig.update_layout(autosize=False, width=550, height=500)
# do not use the k format for the thousands
fig.update_layout(yaxis = dict(exponentformat = 'none'))
# tick every 2eV
fig.update_layout( xaxis = dict(tickmode = 'linear',tick0 = 0,dtick = 2))




fig.add_trace(go.Scatter(mode='markers', marker=dict(size=12, color=colors[0],opacity=0.5),
                                x=XPS["B.E."].values,
                                 y=XPS["CPS"].values-XPS["Background CPS"].values))

fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[1],dash='dot'),
                                 x=XPS["B.E."].values,
                                 y=XPS["N-C/H.1"].values-XPS["Background CPS"].values))

fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[2],dash='dot'),
                                 x=XPS["B.E."].values,
                                 y=XPS["N-O.1"].values-XPS["Background CPS"].values))

fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[3],dash='dot'),
                                 x=XPS["B.E."].values,
                                 y=XPS["N+.1"].values-XPS["Background CPS"].values))


fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[7],dash='dash'),
                                 x=XPS["B.E."].values,
                                 y=XPS["Envelope CPS"].values-XPS["Background CPS"].values))

fig.update_layout(showlegend=False)

fig.show()

fig.write_image("C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Thesis/Chapters/Methods and Materials"+"/"+"XPS_N1s"+".png")
fig.write_image("C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Thesis/Chapters/Methods and Materials"+"/"+"XPS_N1s"+".svg")
fig.write_html("C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Thesis/Chapters/Methods and Materials"+"/"+"XPS_N1s"+".html")

# %% [markdown]
# ## TEMPO

# %% [markdown]
# ### Wide

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/TEMPO/"
Folders=["0021_300321_AQ","0021_300321_AQ","0021_300321_AQ","0021_300321_AQ","0021_300321_AQ"]

Peak="Wide"
Files=["Au","HOPG","Si","PTFE"]
titles=Files
for i in range(len(Files)):
    Files[i] = Files[i]+Peak

titles=["Au", "HOPG","Si"]
symbol=["circle","square","cross", "diamond","triangle-up","pentagon"]
#names=["5s Upstream", "5s Middle","300s Upstream", "300s Middle"]
Names=["5 s","300 s", "600 s"]
colors=["blue", "black","red"]
Letters=["a)","b)","c)","d)","e)","f)","g)","h)","i)", "l)"]



length=1214 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
fig = make_subplots(rows=4, cols=1,
                    vertical_spacing=0.05,horizontal_spacing=0.05,
                    shared_xaxes=True, shared_yaxes=True,
                    #subplot_titles=("Glow", "Afterglow")
                   )

#white background
fig.update_layout(template="plotly_white")
#x-axis
fig.update_xaxes(autorange = "reversed")
#fig.update_xaxes(domain=[0.7,0.0])
#
fig.update_xaxes(title='Binding Energy (eV)', row=4, col=1)
fig.update_xaxes(title='Binding Energy (eV)', row=4, col=2)
fig.update_xaxes(title='Binding Energy (eV)', row=4, col=3)
#y-axis
fig.update_yaxes(title='Intensity (a.u.)')
fig.update_yaxes(showticklabels=False, title_standoff = 30 )


#font size
fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
fig.update_layout(font=dict(size=23))
fig.update_annotations(font_size=30)     #dimensions of the titles
#add the black box around the graph
fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
#add black ticks
fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
fig.update_layout(legend=dict(yanchor="top",y=0.97,xanchor="right",x=0.22))
fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=50))
fig.update_layout(autosize=False, width=800, height=1100)
fig.update_yaxes(exponentformat = 'power')

#letters for the panels
s=0
for n in range(0,4):
    for m in range(0,1):
    
        fig.add_annotation(xref="x domain", yref="y domain",x=0.03, y=0.95,text=Letters[s],
                           showarrow=False, yshift=10, col=1+m, row=1+n)
        s=s+1


for j in range(0,len(Files)):
    
    
    FolderTR=Path+Folders[j]
    DataPerSpectrum=int(DataPerSpectra[j]) #number of rows of each spectrum including the headers
    FileXPS=Files[j]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    #number of spectra composing the dataset
    NumberOfSpectra=(XPS.shape[0]//NumericDataPerSpectrum)
    
    Mask=np.logical_and(XPS["Binding Energy"] >0, XPS["Binding Energy"] < 1200)
    XPS=XPS[Mask]

    x_len=XPS.shape[0]//NumberOfSpectra

    for i in range (0, NumberOfSpectra):
            
        if (i%2==0):
            
            fig.add_trace(go.Scatter(line=dict(color=colors[i//2]),
                                     x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
                                     y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i]+14000*i,
                                     name=Names[i//2]),row=1+j, col=1+0)
            
        #if (i%2==1):
            
            #fig.add_trace(go.Scatter(line=dict(color=colors[i//2]),
                                     #x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[i],
                                     #y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[i],
                                     #name=Names[i//2]),row=1+j, col=1+1)
            
    names = set()
    fig.for_each_trace(
            lambda trace:
                trace.update(showlegend=False)
                if (trace.name in names) else names.add(trace.name))

#Peaks labels
fig.add_vline(x=400, line_dash="dash", line=dict(width=1), annotation_text="N<br>1s", annotation=dict(font_size=18))
fig.add_vline(x=532, line_dash="dash", line=dict(width=1), annotation_text="O<br>1s", annotation=dict(font_size=18))
fig.add_vline(x=285, line_dash="dash", line=dict(width=1), annotation_text="C<br>1s", annotation=dict(font_size=18))
fig.add_vline(x=84, line_dash="dash", line=dict(width=1), annotation_text="Au<br>4f", annotation=dict(font_size=18), row=1)
fig.add_vline(x=99.4, line_dash="dash", line=dict(width=1), annotation_text="Si<br>2p", annotation=dict(font_size=18), row=3)
fig.add_vline(x=150, line_dash="dash", line=dict(width=1), annotation_text="Si<br>2s", annotation=dict(font_size=18), row=3)
fig.add_vline(x=688, line_dash="dash", line=dict(width=1), annotation_text="F<br>1s", annotation=dict(font_size=18), row=4)


Path_s="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Thesis/Chapters/TEMPO"     
fig.write_image(Path_s+"/"+"Wide"+".svg")
fig.write_image(Path_s+"/"+"Wide"+".png")
fig.show()

# %% [markdown]
# ### High resolution

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/TEMPO/"
Folders=["0021_300321_AQ","0021_300321_AQ","0021_300321_AQ","0021_300321_AQ","0021_300321_AQ"]
Peak="N1s"

Files=["Au","HOPG","Si","PTFE"]
for i in range(len(Files)):
    Files[i] = Files[i]+Peak
 
names=["Au","HOPG","Si","PTFE"]
titles=["5s Upstream", "5s Middle","300s Upstream", "300s Middle","600s Upstream", "600s Middle"]

symbol=["circle","cross","triangle-up","square","diamond"]
colors=["blue", "black","red", "orange","green"]


length=169 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

# %%
for j in range (0,len(titles)):
    
    print(titles[j])
    fig = go.Figure()
    fig.update_layout(template="plotly_white")
    fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='CPS')
    fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
    fig.update_layout(font=dict(size=23))
    #add the black box around the graph
    fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    #add black ticks
    fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
    fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
    
    fig.update_layout(xaxis = dict(autorange = "reversed"))
    fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
    fig.update_layout(autosize=False, width=550, height=500)
    
    fig.add_vline(x=399, line_dash="dash",annotation_text="N-C")
    fig.add_vline(x=400, line_dash="dash",annotation_text="N-O")
    fig.add_vline(x=401.5, line_dash="dash",annotation_text="N+")
    


    for i in range(0,len(Files)):
        

        FolderTR=Path+Folders[i]
        DataPerSpectrum=int(DataPerSpectra[i]) #number of rows of each spectrum including the headers
        FileXPS=Files[i]
        NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
        
        
        #Read the XPS data and assign them to a pandas dataframe
        XPS=xl.ReadXPSData(FolderTR, FileXPS)
        
        #number of spectra composing the dataset
        NumberOfSpectra=(XPS.shape[0]//NumericDataPerSpectrum)

        XPS=xl.RemoveLinearBackgorund(XPS, Points=30, NumberOfSpectra=NumberOfSpectra)
        
        Mask=np.logical_and( XPS["Binding Energy"] >396, XPS["Binding Energy"] < 404)
        XPS=XPS[Mask]

        x_len=XPS.shape[0]//NumberOfSpectra

        fig.add_trace(go.Scatter(mode='markers',marker_symbol=symbol[i], marker=dict(size=12, color=colors[i], opacity=0.6),
                                 x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[j],
                                 y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[j],
                                 name=names[i]))

    

    Path_s="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Thesis/Chapters/TEMPO"     
    fig.write_image(Path_s+"/"+ "XPS_Raw"+ "/"+titles[j]+".svg")
    fig.write_image(Path_s+"/"+ "XPS_Raw"+ "/"+titles[j]+".png")
    fig.show()

# %% [markdown]
# ### Fitted Data

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/TEMPO/"
Folders=["0021_300321_AQ","0021_300321_AQ"]
Files=["N1sFitted_plusPTFE"]

length=169 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

colors=["gray", "blue", "red", "black", "orange"]
Letters=["a)","b)","c)","d)","e)","f)","g)","h)","i)", "l)"]
Times=["5 s"," 5 s","5 s","5","300 s","300 s","300 s","300 s","600 s","600 s","600 s","600 s"]

#columns of the file to read
Columns=["K.E.", "Counts", "N-C K.E.", "N-O K.E.", "N+ K.E.", "Background", "Envelope",
"Binding Energy", "CPS", "N-C", "N-O", "N+", "Background CPS", "Envelope CPS"]

# %%
 for i in range(0,len(Files)):
        

    FolderTR=Path+Folders[i]
    DataPerSpectrum=int(DataPerSpectra[i]) #number of rows of each spectrum including the headers
    FileXPS=Files[i]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    print(NumericDataPerSpectrum)
        
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSDataFitted(FolderTR, Files[i], HeaderColumns, Columns)
    NumberOfSpectra=(XPS.shape[0]//NumericDataPerSpectrum)
    Mask=np.logical_and( XPS["Binding Energy"] >396, XPS["Binding Energy"] < 404)
    XPS=XPS[Mask]
    print(XPS.shape[0])
    print(NumberOfSpectra)
    x_len=(XPS.shape[0]//NumberOfSpectra)
        
    fig = make_subplots(rows=4, cols=3, #subplot_titles=("HOPG", "Au(111)", "SiO<sub>2"),
                        shared_xaxes=True, shared_yaxes=True,
                        vertical_spacing=0.05)
    
    
    #white background
    fig.update_layout(template="plotly_white")
    #x-axis
    fig.update_xaxes(autorange = "reversed")
    fig.update_xaxes(title='Binding Energy (eV)', row=4, col=1)
    fig.update_xaxes(title='Binding Energy (eV)', row=4, col=2)
    fig.update_xaxes(title='Binding Energy (eV)', row=4, col=3)
    #y-axis
    fig.update_yaxes(title='Intensity (CPS)', row=1, col=1)
    fig.update_yaxes(title='Intensity (CPS)', row=2, col=1)
    fig.update_yaxes(title='Intensity (CPS)', row=3, col=1)
    #font size
    fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
    fig.update_layout(font=dict(size=23))
    fig.update_annotations(font_size=30)     #dimensions of the titles
    #add the black box around the graph
    fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
    #add black ticks
    fig.update_xaxes(showgrid=True,ticks="outside",tickwidth=4)
    fig.update_yaxes(showgrid=True,ticks="outside",tickwidth=4)
    #fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.10))
    fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=50))
    fig.update_layout(autosize=False, width=1400, height=1000)

    j=0
    
    print (Files[i])
    for k in range (0, 4):
        for l in range(0,3):

            fig.add_trace(go.Scatter(mode='markers', marker=dict(size=12, color=colors[0],opacity=0.5),
                                        x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[j],
                                        y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[j]-
                                         XPS["Background CPS"].values.reshape(NumberOfSpectra,x_len)[j],
                                         name="Data"),
                                          col=1+l, row=1+k)
            fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[1],dash='dot'),
                                        x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[j],
                                        y=XPS["N-C"].values.reshape(NumberOfSpectra,x_len)[j]-
                                         XPS["Background CPS"].values.reshape(NumberOfSpectra,x_len)[j],
                                        name="N-C"),
                                         col=1+l, row=1+k)
            fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[2],dash='dot'),
                                        x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[j],
                                        y=XPS["N-O"].values.reshape(NumberOfSpectra,x_len)[j]-
                                         XPS["Background CPS"].values.reshape(NumberOfSpectra,x_len)[j],
                                        name="N-O"),
                                         col=1+l, row=1+k)
            fig.add_trace(go.Scatter(mode='lines', line=dict(width=4, color=colors[3],dash='dot'),
                                        x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[j],
                                        y=XPS["N+"].values.reshape(NumberOfSpectra,x_len)[j]-
                                         XPS["Background CPS"].values.reshape(NumberOfSpectra,x_len)[j],
                                        name="N+"),
                                         col=1+l, row=1+k)
            fig.add_trace(go.Scatter(mode='lines', line=dict(width=5, color=colors[4],dash="dash"),
                                        x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[j],
                                        y=XPS["N-C"].values.reshape(NumberOfSpectra,x_len)[j]+
                                        XPS["N-O"].values.reshape(NumberOfSpectra,x_len)[j]+
                                        XPS["N+"].values.reshape(NumberOfSpectra,x_len)[j]-
                                         3*XPS["Background CPS"].values.reshape(NumberOfSpectra,x_len)[j],
                                        name="Envelope"),
                                         col=1+l, row=1+k)
            
            fig.add_annotation(xref="x domain", yref="y domain",x=0.05, y=0.95, text=Letters[j], showarrow=False, yshift=10, col=1+l, row=1+k)
            fig.add_annotation(xref="x domain", yref="y domain",x=0.95, y=0.95, text=Times[j], showarrow=False, yshift=10, col=1+l, row=1+k)

            j=j+1
    names = set()
    fig.for_each_trace(
            lambda trace:
                trace.update(showlegend=False)
                if (trace.name in names) else names.add(trace.name))
    #fig.write_image(FolderTR+"/"+Files[i]+".svg")
    #fig.write_image(FolderTR+"/"+Files[i]+".pdf")
    fig.show()

# %% [markdown]
# ### XPS microbiology

# %%
Path="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Data/XPS/TEMPO/antimicrobial/"
Folders=["0004_250423_AQ","0004_250423_AQ", "0004_250423_AQ"]
Files=["N1s_PP", "N1s_vapour", "n1s_comb"]

length=169 #number of rows of each spectrum including the headers
DataPerSpectra=np.zeros(len(Files))
for i in range (len(Files)):
    DataPerSpectra[i]=length
HeaderColumns=8 #number of columns comprising the headers

markers=['circle', 'square', 'diamond']
colors=["blue", "red", "orange"]
names=['PP', 'Vapour', 'Combined']

# %%
fig = go.Figure()
 
for i in range(0,len(Files)):
        
    FolderTR=Path+Folders[i]
    DataPerSpectrum=int(DataPerSpectra[i]) #number of rows of each spectrum including the headers
    FileXPS=Files[i]
    NumericDataPerSpectrum=xl.Count_DataPerSpectrum(FolderTR + "/"+ FileXPS)-HeaderColumns #number of rows with the numeric data
    
        
    #Read the XPS data and assign them to a pandas dataframe
    XPS=xl.ReadXPSData(FolderTR, FileXPS)
    NumberOfSpectra=(XPS.shape[0]//NumericDataPerSpectrum)
    XPS=xl.RemoveLinearBackgorund(XPS, Points=30, NumberOfSpectra=NumberOfSpectra)
    #Mask=np.logical_and( XPS["Binding Energy"] >396, XPS["Binding Energy"] < 404)
    #XPS=XPS[Mask]
    x_len=(XPS.shape[0]//NumberOfSpectra)
    
    fig.add_trace(go.Scatter(mode='markers', marker_symbol=markers[i],marker=dict(size=12, color=colors[i],opacity=0.5),
                            x=XPS["Binding Energy"].values.reshape(NumberOfSpectra,x_len)[0],
                            y=XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[0]- np.min(XPS["CPS"].values.reshape(NumberOfSpectra,x_len)[0]),
                            name=names[i]))
    
    
fig.update_layout(template="plotly_white")
fig.update_layout(xaxis_title='Binding Energy (eV)', yaxis_title='Intesnity (CPS)')
fig.update_layout(yaxis = dict( tickfont = dict(size = 23)), xaxis = dict( tickfont = dict(size = 23)))
fig.update_layout(font=dict(size=23))
#add the black box around the graph
fig.update_xaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=4, linecolor='black', mirror=True)
#add black ticks
fig.update_xaxes(showgrid=True,ticks="inside",tickwidth=4)
fig.update_yaxes(showgrid=True,ticks="inside",tickwidth=4)
    
fig.update_layout(xaxis = dict(range = [405,395]))
fig.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="right",x=0.99))
fig.update_layout(margin=go.layout.Margin(l=0,r=0,b=20,t=0)) #t=50
fig.update_layout(autosize=False, width=600, height=300)
fig.update_layout(yaxis = dict(exponentformat = 'none'))

        
Path_s="C:/Users/quadrell/OneDrive - Lancaster University/PhD Project/Thesis/Chapters/TEMPO"     
fig.write_image(Path_s+"/"+ "Microbiology_XPS"+ ".svg")
fig.write_image(Path_s+"/"+ "Microbiology_XPS"+ ".png")
fig.show()
